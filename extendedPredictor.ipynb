# %%
from gensim.models import KeyedVectors
import pandas as pd
import numpy as np
import tensorflow as tf
import csv
import operator
import preprocessor as pre
import regex

# %% [markdown]
# ## 1 Prediction Model

# %%
# Load Turkish Fasttext model
fasttextModel = KeyedVectors.load_word2vec_format('data/fasttext/wiki.tr.vec')

# %%
# Load Data into a data-frame
# There should be all the account for four different categories
# Since, I removed 10 out of 12 account before putting into Github, there are only two sample accounts
retrievedAccounts = ["iksv_istanbul","ntvksanat"]

dataFrameList = []
for anAccount in retrievedAccounts:
    dataframe = pd.read_csv("data/trainAccount/" + anAccount + '_cleaned.csv', sep=',', header=None, names=["label","tweets"])
    dataFrameList.append(dataframe)
gatheredDataFrame= pd.concat(dataFrameList).sample(frac=1).reset_index(drop=True)

# %%
# Seperate tweets and labels into to data-frames
tweets = gatheredDataFrame['tweets'].values
labels = gatheredDataFrame['label'].values

# %%
# Convert labels to binary representations
labelMapper = {"politics":[1,0,0,0], "art":[0,1,0,0], "society":[0,0,1,0], "charity":[0,0,0,1]}
labelsConverted = []
for label in labels:
    labelsConverted.append(labelMapper[label])

# %%
# Function to avarage all word-vectors (calculating with provided model) within a sentence
def bagOfWords(sentences, model, vectorLength):
    returnMatrix = []
    for sentence in sentences:
        words = sentence.split()
        wordCount = len(words)
        temporaryList = np.zeros(vectorLength)
        for word in words:
            try:
                temporaryList += model[word]
            except:
                wordCount -= 1
        if wordCount == 0:
            avarageList = np.zeros(vectorLength)
        else:
            avarageList = temporaryList/wordCount
        returnMatrix.append(avarageList)
    return returnMatrix

# %%
vectorLength = 300
# Convert tweets into bag-of-words representation
bagOfWordsMatrix = bagOfWords(tweets, fasttextModel, vectorLength)

# %%
# Split data as train and test with the ratio 4/5
sperator = int(len(bagOfWordsMatrix)*4/5)
trainFeature = np.array(bagOfWordsMatrix[:sperator])
trainLabel = np.array(labelsConverted[:sperator])
testFeature = np.array(bagOfWordsMatrix[sperator:])
testLabel = np.array(labelsConverted[sperator:])

# %%
trainCount = sperator
testCount = len(bagOfWordsMatrix) - len(trainFeature)

# %%
# Set Parameters for neural network
learningRate = 0.001
trainingEpochs = 150
batchSize = 128
displayStep = 1
inputLayer = vectorLength
firstHidden = 2 ** 6
secondHidden = 2 ** 7
outputLayer = 2 ** 2

# %%
# Tensorflow arrangements
x = tf.placeholder("float", [None, inputLayer])
y = tf.placeholder("float", [None, outputLayer])

# Function of a neural network model
def multilayerPerceptron(x, weights, biases):
    # Hidden layer with RELU activation
    firstLayer = tf.add(tf.matmul(x, weights['h1']), biases['b1'])
    firstLayer = tf.nn.relu(firstLayer)
    # Hidden layer with RELU activation
    secondLayer = tf.add(tf.matmul(firstLayer, weights['h2']), biases['b2'])
    secondLayer = tf.nn.relu(secondLayer)
    # Output layer with linear activation
    outputLayer = tf.matmul(secondLayer, weights['out']) + biases['out']
    return outputLayer

# %%
# Store weight and biases of each layer
weights = {
    'h1': tf.Variable(tf.random_normal([inputLayer, firstHidden])),
    'h2': tf.Variable(tf.random_normal([firstHidden, secondHidden])),
    'out': tf.Variable(tf.random_normal([secondHidden, outputLayer]))}
biases = {
    'b1': tf.Variable(tf.random_normal([firstHidden])),
    'b2': tf.Variable(tf.random_normal([secondHidden])),
    'out': tf.Variable(tf.random_normal([outputLayer]))}

# Construct the model
prediction = multilayerPerceptron(x, weights, biases)

# Define loss and optimizer function
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y, logits=prediction))
optimizer = tf.train.AdamOptimizer(learning_rate=learningRate).minimize(cost)

# Initializing the Variables
initializer = tf.global_variables_initializer()

# Calculate accuracy
correctPredictions = tf.equal(tf.argmax(prediction, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correctPredictions, "float"))

# %%
session = tf.Session()
session.run(initializer)

# Training cycle
for epoch in range(trainingEpochs):
    averageCost = 0.
    totalBatch = int(trainCount/batchSize)

    # Loop over all batches
    batchCounter = 0
    for i in range(totalBatch):
        batchFeature, batchLabel = trainFeature[batchCounter:batchCounter + batchSize],\
                                   trainLabel[batchCounter:batchCounter + batchSize]
        # Run optimization and cost operations
        _, c = session.run([optimizer, cost], feed_dict={x: batchFeature, y: batchLabel})

        # Calculate average cost
        averageCost += c / totalBatch
        batchCounter = batchCounter + batchSize

    if epoch % displayStep == 0:
        print("Epoch:", '%04d' % (epoch+1), "cost=", "{:.9f}".format(averageCost))

print("Optimization Finished!\n")
# Out:
# Epoch: 0001 cost= 48.537809552
# Epoch: 0002 cost= 16.171645204
# Epoch: 0003 cost= 11.212101183
# Epoch: 0004 cost= 8.639849621
# Epoch: 0005 cost= 6.996074763
# Epoch: 0006 cost= 5.833510590
# Epoch: 0007 cost= 4.943300272
# Epoch: 0008 cost= 4.242936794
# Epoch: 0009 cost= 3.666098441
# Epoch: 0010 cost= 3.186154503
# Epoch: 0011 cost= 2.782363186
# Epoch: 0012 cost= 2.451660262
# Epoch: 0013 cost= 2.174097709
# Epoch: 0014 cost= 1.936227339
# Epoch: 0015 cost= 1.733503498
# Epoch: 0016 cost= 1.564142109
# Epoch: 0017 cost= 1.419505253
# Epoch: 0018 cost= 1.297071832
# Epoch: 0019 cost= 1.193733717
# Epoch: 0020 cost= 1.104215101
# Epoch: 0021 cost= 1.025567705
# Epoch: 0022 cost= 0.957372121
# Epoch: 0023 cost= 0.898226658
# Epoch: 0024 cost= 0.846043421
# Epoch: 0025 cost= 0.800914506
# Epoch: 0026 cost= 0.762501714
# Epoch: 0027 cost= 0.727833680
# Epoch: 0028 cost= 0.697354016
# Epoch: 0029 cost= 0.669916745
# Epoch: 0030 cost= 0.645100099
# Epoch: 0031 cost= 0.622358245
# Epoch: 0032 cost= 0.601191793
# Epoch: 0033 cost= 0.582101635
# Epoch: 0034 cost= 0.564335163
# Epoch: 0035 cost= 0.548343104
# Epoch: 0036 cost= 0.533598155
# Epoch: 0037 cost= 0.520240645
# Epoch: 0038 cost= 0.507402442
# Epoch: 0039 cost= 0.495031719
# Epoch: 0040 cost= 0.484140683
# Epoch: 0041 cost= 0.473554671
# Epoch: 0042 cost= 0.463974129
# Epoch: 0043 cost= 0.454873827
# Epoch: 0044 cost= 0.445319951
# Epoch: 0045 cost= 0.437106068
# Epoch: 0046 cost= 0.428066114
# Epoch: 0047 cost= 0.420184379
# Epoch: 0048 cost= 0.412340839
# Epoch: 0049 cost= 0.405272589
# Epoch: 0050 cost= 0.398865090
# Epoch: 0051 cost= 0.392054392
# Epoch: 0052 cost= 0.386670597
# Epoch: 0053 cost= 0.380033311
# Epoch: 0054 cost= 0.374095683
# Epoch: 0055 cost= 0.368747430
# Epoch: 0056 cost= 0.363097419
# Epoch: 0057 cost= 0.358065024
# Epoch: 0058 cost= 0.353496664
# Epoch: 0059 cost= 0.349986335
# Epoch: 0060 cost= 0.344517657
# Epoch: 0061 cost= 0.339774467
# Epoch: 0062 cost= 0.335529075
# Epoch: 0063 cost= 0.331641667
# Epoch: 0064 cost= 0.327329786
# Epoch: 0065 cost= 0.323813595
# Epoch: 0066 cost= 0.319344529
# Epoch: 0067 cost= 0.316711357
# Epoch: 0068 cost= 0.312956907
# Epoch: 0069 cost= 0.309182523
# Epoch: 0070 cost= 0.305605488
# Epoch: 0071 cost= 0.302830777
# Epoch: 0072 cost= 0.299486665
# Epoch: 0073 cost= 0.296470004
# Epoch: 0074 cost= 0.293058448
# Epoch: 0075 cost= 0.288655520
# Epoch: 0076 cost= 0.286192508
# Epoch: 0077 cost= 0.284321249
# Epoch: 0078 cost= 0.282244015
# Epoch: 0079 cost= 0.278127778
# Epoch: 0080 cost= 0.274612541
# Epoch: 0081 cost= 0.272797192
# Epoch: 0082 cost= 0.269503327
# Epoch: 0083 cost= 0.267345484
# Epoch: 0084 cost= 0.264651568
# Epoch: 0085 cost= 0.262842843
# Epoch: 0086 cost= 0.260065349
# Epoch: 0087 cost= 0.259170490
# Epoch: 0088 cost= 0.257325005
# Epoch: 0089 cost= 0.256730354
# Epoch: 0090 cost= 0.254601769
# Epoch: 0091 cost= 0.254188598
# Epoch: 0092 cost= 0.253069984
# Epoch: 0093 cost= 0.253559233
# Epoch: 0094 cost= 0.251584111
# Epoch: 0095 cost= 0.249900596
# Epoch: 0096 cost= 0.245753327
# Epoch: 0097 cost= 0.241525234
# Epoch: 0098 cost= 0.236034001
# Epoch: 0099 cost= 0.232620622
# Epoch: 0100 cost= 0.228117536
# Epoch: 0101 cost= 0.226352477
# Epoch: 0102 cost= 0.221575995
# Epoch: 0103 cost= 0.220029490
# Epoch: 0104 cost= 0.216074908
# Epoch: 0105 cost= 0.214444566
# Epoch: 0106 cost= 0.211059989
# Epoch: 0107 cost= 0.209038914
# Epoch: 0108 cost= 0.206626412
# Epoch: 0109 cost= 0.204452969
# Epoch: 0110 cost= 0.201769394
# Epoch: 0111 cost= 0.200133098
# Epoch: 0112 cost= 0.197894784
# Epoch: 0113 cost= 0.196535738
# Epoch: 0114 cost= 0.194790825
# Epoch: 0115 cost= 0.193003999
# Epoch: 0116 cost= 0.191661689
# Epoch: 0117 cost= 0.190073078
# Epoch: 0118 cost= 0.187710596
# Epoch: 0119 cost= 0.186670928
# Epoch: 0120 cost= 0.184477220
# Epoch: 0121 cost= 0.183505418
# Epoch: 0122 cost= 0.181597378
# Epoch: 0123 cost= 0.180818176
# Epoch: 0124 cost= 0.178742422
# Epoch: 0125 cost= 0.178073868
# Epoch: 0126 cost= 0.176260286
# Epoch: 0127 cost= 0.175679528
# Epoch: 0128 cost= 0.174358444
# Epoch: 0129 cost= 0.173731929
# Epoch: 0130 cost= 0.171212047
# Epoch: 0131 cost= 0.168661379
# Epoch: 0132 cost= 0.168285988
# Epoch: 0133 cost= 0.166174973
# Epoch: 0134 cost= 0.164722393
# Epoch: 0135 cost= 0.163488067
# Epoch: 0136 cost= 0.161724635
# Epoch: 0137 cost= 0.160888119
# Epoch: 0138 cost= 0.159427477
# Epoch: 0139 cost= 0.158190784
# Epoch: 0140 cost= 0.156100502
# Epoch: 0141 cost= 0.154966679
# Epoch: 0142 cost= 0.153372291
# Epoch: 0143 cost= 0.152495083
# Epoch: 0144 cost= 0.151185266
# Epoch: 0145 cost= 0.149989745
# Epoch: 0146 cost= 0.149915197
# Epoch: 0147 cost= 0.147758023
# Epoch: 0148 cost= 0.146072890
# Epoch: 0149 cost= 0.144675038
# Epoch: 0150 cost= 0.142729498
# Optimization Finished!

# %%
# Calculate Accuracy 
correctPredictions = tf.equal(tf.argmax(prediction, 1), tf.argmax(y, 1))
accuracyTensor = tf.reduce_mean(tf.cast(correctPredictions, "float"))
probabilityLabels = tf.argmax(prediction, 1)
trainAccuracy, _ = session.run([accuracyTensor, probabilityLabels], feed_dict={x:trainFeature, y:trainLabel})
testAccuracy, _ = session.run([accuracyTensor, probabilityLabels], feed_dict={x:testFeature, y:testLabel})

# %%
print("Train Accuracy : %f" % trainAccuracy)
print("Test Accuracy : %f" % testAccuracy)
# Out:
# Train Accuracy : 0.956633
# Test Accuracy : 0.803368

# %% [markdown]
# ## 2 Predicting tweets' labels

# %%
def interestFinder(userName):
  
    # Load user tweets and assign a label to each of them
    currentDataframe = pd.read_csv("data/clean/" + userName + '_cleaned.csv', sep=',', header=None, names=["label","tweets"])
    currentTweets = currentDataframe['tweets'].values
    currentBagOfWordsMatrix = bagOfWords(currentTweets, fasttextModel, 300)
    prediction = multilayerPerceptron(x, weights, biases)
    probabilityLabels = tf.argmax(prediction, 1)
    predictedLabels = session.run(probabilityLabels, feed_dict={x:currentBagOfWordsMatrix})
    
    # Calculate frequency of labels
    labelCount = {"politics":0, "art":0, "society":0, "charity":0}
    for prediction in predictedLabels:
        if prediction == 0:
            labelCount['politics'] += 1
        elif prediction == 1:
            labelCount['art'] += 1
        elif prediction == 2:
            labelCount['society'] += 1
        elif prediction == 3:
            labelCount['charity'] += 1
    
    total = float(len(currentDataframe))
    labelFrequency = {key: value / total for key, value in labelCount.iteritems()}
    return labelFrequency

# %%
# Open input file to retrieve users from and a file to write topic distribution of each user
inputFile = open('data/graph/node.csv', 'rt')
outputFile = open('data/graph/nodeWithScore.csv', 'wt')
reader = csv.reader(inputFile)
writer = csv.writer(outputFile, delimiter=',', lineterminator='\n')
writer.writerow(['', 'id', 'label', 'politics', 'art', 'society', 'charity', 'interest'])

# %%
for line in reader:
    userName = line[2]
    interestDictionary = {"politics":0, "art":0, "society":0, "charity":0}
    mainInterest = "n/a"
    
    if userName != "n/a":
        try: 
            # Load user tweets and assign a label to each of them
            currentDataframe = pd.read_csv("data/clean/" + userName + '_cleaned.csv', sep=',', header=None, names=["label","tweets"])
            currentTweets = currentDataframe['tweets'].values
            currentBagOfWordsMatrix = bagOfWords(currentTweets, fasttextModel, 300)
            predictedLabels = session.run(probabilityLabels, feed_dict={x:currentBagOfWordsMatrix})

            # Calculate frequency of labels
            labelCount = {"politics":0, "art":0, "society":0, "charity":0}
            for prediction in predictedLabels:
                if prediction == 0:
                    labelCount['politics'] += 1
                elif prediction == 1:
                    labelCount['art'] += 1
                elif prediction == 2:
                    labelCount['society'] += 1
                elif prediction == 3:
                    labelCount['charity'] += 1

            total = float(len(currentDataframe))
            interestDictionary = {key: value / total for key, value in labelCount.items()}
            mainInterest = max(interestDictionary.items(), key=operator.itemgetter(1))[0]
            print("Success : %s" % userName)

        except Exception as error:
            print("Error : %s for %s" % (error, userName))

    writer.writerow([line[0], line[1], line[2], interestDictionary['politics'], 
                     interestDictionary['art'], interestDictionary['society'],
                     interestDictionary['charity'], mainInterest])
# Out:
# User : alicankanoglu
# Error : File b'data/clean/alicankanoglu_cleaned.csv' does not exist
# User : sehir_edebiyat
# User : handetuzlakoglu
# Error : File b'data/clean/handetuzlakoglu_cleaned.csv' does not exist
# User : safakmhmt
# Error : File b'data/clean/safakmhmt_cleaned.csv' does not exist
# User : furkanemer43
# User : psikologvari
# Error : File b'data/clean/psikologvari_cleaned.csv' does not exist
# User : n/a
# User : Beyanor
# User : rkahrmn
# Error : File b'data/clean/rkahrmn_cleaned.csv' does not exist
# User : SivilSehirli
# Error : File b'data/clean/SivilSehirli_cleaned.csv' does not exist
# User : zeynephepi
# User : DemirlerinYavuz
# User : necmettinndogan
# User : philobuny
# User : sabankardas
# User : ahmet_ors
# User : htcugurist
# User : Marmaraaa
# User : Donoughtella
# User : usamedegirmenci
# Error : File b'data/clean/usamedegirmenci_cleaned.csv' does not exist
# User : SehirClubs
# User : ozhanneslihan
# Error : File b'data/clean/ozhanneslihan_cleaned.csv' does not exist
# User : bvuslatcelik
# User : zepaltinbas
# User : mhmmtmz
# User : ssuheyl
# User : zeynepkoyuncu_
# Error : File b'data/clean/zeynepkoyuncu__cleaned.csv' does not exist
# User : di__rapunzel
# Error : File b'data/clean/di__rapunzel_cleaned.csv' does not exist
# User : glcnavsar
# User : burakincecik
# User : sosyalbilimler
# User : BabaOnurbaba02
# User : TSAorgtr
# User : sehirKIZILAY
# User : burhanduran
# User : NurOzyayla
# User : sehirgundemi
# User : turanmeryemm
# Error : Cannot feed value of shape (0,) for Tensor 'Placeholder:0', which has shape '(?, 300)'
# User : kulturistan
# User : mefuslu
# User : farukagrali
# User : diaspora_turk
# User : bubirisaret
# User : cetinkoc
# User : dunyabizim
# User : enesogIu
# User : ustkatsakini
# User : mutlutarih
# Error : File b'data/clean/mutlutarih_cleaned.csv' does not exist
# User : Hsyn_Uynk
# User : Sehir_Law
# User : ihsanelhan
# User : FeyyazDerinoglu
# User : Directoroyun
# User : smyyakgul
# Error : File b'data/clean/smyyakgul_cleaned.csv' does not exist
# User : sfsckesc
# Error : Cannot feed value of shape (0,) for Tensor 'Placeholder:0', which has shape '(?, 300)'
# User : Haluket
# User : Nocryletstry
# User : serhatnasiroglu
# User : beyzanurkocak_
# User : m_emreaydin
# Error : File b'data/clean/m_emreaydin_cleaned.csv' does not exist
# User : zuhalnurbanu
# User : gulsumkavuncu
# User : aeser_
# User : universiteprog
# User : ilkebu
# User : Twltter56480961
# Error : File b'data/clean/Twltter56480961_cleaned.csv' does not exist
# User : Jllykss
# User : yensaroglu
# User : rbcebeci
# User : at_abisi
# User : MohsawThe
# User : saruhanoguzhan
# User : MurekkepDusunce
# User : DumbDuckkk
# User : ensargul
# User : opsesiff
# User : amnaalellam
# User : sharno3
# User : frkntemiz
# User : mcs1597
# User : EnesEtlik
# Error : File b'data/clean/EnesEtlik_cleaned.csv' does not exist
# User : OzSehirP
# User : hsnasdfghj
# User : mervecban
# User : akyollahmet
# User : NoliUla
# User : kplnabdullahh
# User : SerdarSanlier
# User : ebrukayaalp
# User : SehirCycling
# Error : File b'data/clean/SehirCycling_cleaned.csv' does not exist
# User : zenubya_
# User : halemek
# User : ArtanKubra
# Error : File b'data/clean/ArtanKubra_cleaned.csv' does not exist
# User : cumartesiannesi
# Error : File b'data/clean/cumartesiannesi_cleaned.csv' does not exist
# User : abo_bery
# User : muhittinEozkan
# User : iphilocalist
# Error : File b'data/clean/iphilocalist_cleaned.csv' does not exist
# User : kardelen62
# User : ayehalhali
# Error : File b'data/clean/ayehalhali_cleaned.csv' does not exist
# User : gaziiseker
# Error : File b'data/clean/gaziiseker_cleaned.csv' does not exist
# User : TahirAbbas_
# Error : Cannot feed value of shape (0,) for Tensor 'Placeholder:0', which has shape '(?, 300)'
# User : SuheylUtku
# User : ikalin1
# User : dilmencern
# User : feyzagoksu_
# Error : File b'data/clean/feyzagoksu__cleaned.csv' does not exist
# User : tokfirdevs
# User : ikibarr
# Error : File b'data/clean/ikibarr_cleaned.csv' does not exist
# User : gastesehir
# Error : File b'data/clean/gastesehir_cleaned.csv' does not exist
# User : sehirmot
# User : mmurataydemir
# Error : File b'data/clean/mmurataydemir_cleaned.csv' does not exist
# User : yasakMIS
# User : DenizBaran_db
# User : SamSehir
# User : omerclb
# Error : File b'data/clean/omerclb_cleaned.csv' does not exist
# User : yrtsvrezgi
# User : MuhittinAtaman
# Error : File b'data/clean/MuhittinAtaman_cleaned.csv' does not exist
# User : serimcetin
# User : Hllibrahim
# User : tarik_tufan
# User : Sehir_Kutuphane
# User : ahmetcemiman
# User : Ahmetaydiiin
# User : AdaletZemini
# User : uniquetekkk
# Error : File b'data/clean/uniquetekkk_cleaned.csv' does not exist
# User : aysealtinay
# User : ameleNotik
# User : Samlikizi
# User : yilmazusakli
# Error : File b'data/clean/yilmazusakli_cleaned.csv' does not exist
# User : batm3nn
# User : ysfzygokcek
# User : Cediddi
# User : OttomanArchive
# User : halilibrahimltr
# Error : File b'data/clean/halilibrahimltr_cleaned.csv' does not exist
# User : emregurlerr
# User : aslitelli
# User : ahmetkusol
# Error : File b'data/clean/ahmetkusol_cleaned.csv' does not exist
# User : mesutyegen
# User : eminesumeyra
# User : birisine1soz
# User : Makbuluttt
# User : hamzalbayrak
# User : fmervekeskin
# User : hikmetogutgen
# User : syukaripinar
# Error : File b'data/clean/syukaripinar_cleaned.csv' does not exist
# User : HesetBrahimi
# User : ahsenbusra
# Error : File b'data/clean/ahsenbusra_cleaned.csv' does not exist
# User : SehirFelsefe
# User : celilcivan
# User : AlibediRzr
# User : o_salha
# Error : Cannot feed value of shape (0,) for Tensor 'Placeholder:0', which has shape '(?, 300)'
# User : AhmetSelim61
# User : senadarici
# User : hakkiuygur1
# User : fundaozerrr
# Error : File b'data/clean/fundaozerrr_cleaned.csv' does not exist
# User : OmerFarukKafali
# User : furkangencer
# User : hilalkoseee
# User : sehirpsychclub
# User : ceylaneb
# User : ebrugun3s
# Error : File b'data/clean/ebrugun3s_cleaned.csv' does not exist
# User : A_Boynukalin
# User : helebilo
# User : ozturkji
# Error : File b'data/clean/ozturkji_cleaned.csv' does not exist
# User : rmznklc2
# User : sedanuraslaner
# Error : File b'data/clean/sedanuraslaner_cleaned.csv' does not exist
# User : PakerMurat
# Error : File b'data/clean/PakerMurat_cleaned.csv' does not exist
# User : emreteke27
# Error : File b'data/clean/emreteke27_cleaned.csv' does not exist
# User : drbetulsayan
# User : rabiaedibe
# User : smrarslan
# Error : File b'data/clean/smrarslan_cleaned.csv' does not exist
# User : mesutyilmaz61
# User : plavileptirr
# User : Muharremdir
# User : Bilalisgoren
# User : tugbatekerek
# User : GeziSehir
# User : etkaiscan
# Error : Cannot feed value of shape (0,) for Tensor 'Placeholder:0', which has shape '(?, 300)'
# User : uluslaras
# Error : File b'data/clean/uluslaras_cleaned.csv' does not exist
# User : n/a
# User : bunyaminbezci
# User : psikologhanem
# User : stlkahve6
# User : yunusalierol
# User : bmeteoglu
# User : Sibai_Homs
# Error : File b'data/clean/Sibai_Homs_cleaned.csv' does not exist
# User : eshylkaratas
# Error : File b'data/clean/eshylkaratas_cleaned.csv' does not exist
# User : evrenmenguc
# Error : File b'data/clean/evrenmenguc_cleaned.csv' does not exist
# User : nisanurhekim
# User : nidarslanbaba
# User : ehuntres
# Error : File b'data/clean/ehuntres_cleaned.csv' does not exist
# User : filozofefendi
# User : burrcylmz
# Error : File b'data/clean/burrcylmz_cleaned.csv' does not exist
# User : onaildogan
# User : selineknci
# User : muharremkilic1
# Error : File b'data/clean/muharremkilic1_cleaned.csv' does not exist
# User : denizilhan
# User : osman7e
# Error : File b'data/clean/osman7e_cleaned.csv' does not exist
# User : Leyla_Ipekci
# User : EnesBasarir
# Error : File b'data/clean/EnesBasarir_cleaned.csv' does not exist
# User : abenesay
# User : ashurehatun
# Error : File b'data/clean/ashurehatun_cleaned.csv' does not exist
# User : tlhclk
# User : acansezgin
# User : dilaradoganer1
# User : Evreki
# User : emintopkaraoglu
# User : SumeyyeI
# Error : File b'data/clean/SumeyyeI_cleaned.csv' does not exist
# User : alimarli_
# User : tkucukcan
# User : ElaAltinay
# User : muminbahlol
# User : ebulferec34
# User : iclalkirman
# User : elfltn
# Error : File b'data/clean/elfltn_cleaned.csv' does not exist
# User : nuraaksu
# Error : File b'data/clean/nuraaksu_cleaned.csv' does not exist
# User : burhankoroglu
# User : f_betul_a
# User : hudaverdiyim
# User : yumnabike
# User : sehircayhane
# User : osmanerken
# User : fatmaaladag
# User : sehir_iletisim
# User : eozkan13
# User : vahap_coskun
# User : ehibba
# User : yusuf_akbal
# User : kubraabasturk
# Error : File b'data/clean/kubraabasturk_cleaned.csv' does not exist
# User : n/a
# User : esmemis
# User : S_Begenjov
# User : betulkocalii
# User : bugraerarslan
# Error : File b'data/clean/bugraerarslan_cleaned.csv' does not exist
# User : gokhanak_ak
# User : Balciceki
# User : hamakirsali
# User : GokhanBacik
# Error : File b'data/clean/GokhanBacik_cleaned.csv' does not exist
# User : pbayrak11
# User : h_suheyl
# User : canacun
# User : sehiryesilay
# User : mhkrgz
# User : wendtist
# User : cengizsunar
# User : ahmdbll
# User : mahmutsami12
# User : Seyyarmasalci
# User : serapsaracli
# User : IDatSEHIR
# User : abdullahbahci1
# User : kureyayinlari
# User : aczvefakr
# User : sulerumeysae
# User : Sinemmpala
# User : Mertmengu
# User : Jaharrad
# User : nedtahir
# User : Academia_ISU
# User : osmnbyrk
# Error : File b'data/clean/osmnbyrk_cleaned.csv' does not exist
# User : eucak
# Error : File b'data/clean/eucak_cleaned.csv' does not exist
# User : arsub_b
# User : MiranCetiner
# User : nihansusinmez
# Error : File b'data/clean/nihansusinmez_cleaned.csv' does not exist
# User : esrapulcu
# Error : File b'data/clean/esrapulcu_cleaned.csv' does not exist
# User : mucahitbilici
# User : goygoyhukuk
# User : AytekinBusra
# User : olpmox
# Error : File b'data/clean/olpmox_cleaned.csv' does not exist
# User : Ordinaryus1907
# Error : File b'data/clean/Ordinaryus1907_cleaned.csv' does not exist
# User : sehiricebreaker
# User : sehirtto
# User : nihanyapar
# User : klmynr
# User : ebu_sehr
# User : ogfurkan
# User : terraincognitae
# User : hatemete
# User : ethemkarademir
# Error : Cannot feed value of shape (0,) for Tensor 'Placeholder:0', which has shape '(?, 300)'
# User : busrasafak
# User : aysegulyesiil
# User : lokmanokten
# User : mutehayyel
# User : denizerbedir
# User : SehirSBE
# User : vesayrevesaire
# User : byazmaci
# User : sehiriletisim
# User : hazarekecik
# User : Lazzyto
# User : aysenurkoc5
# User : zelaldirekcii
# User : ilovecihangir
# Error : File b'data/clean/ilovecihangir_cleaned.csv' does not exist
# User : bejanmatur
# User : reyyanaynur
# User : welfaredist
# User : KyoPino
# User : _mutekellim_
# Error : File b'data/clean/_mutekellim__cleaned.csv' does not exist
# User : Bornimagoo
# User : incinbaa
# User : Yabkanes
# User : Sevdes
# User : yavuzgozeller
# User : eyisen
# User : sehirhaber
# User : cinarkerem
# User : SumeyyeII
# Error : File b'data/clean/SumeyyeII_cleaned.csv' does not exist
# User : tahaun
# User : seyma353
# User : harun5334
# User : Aysegulmek
# User : burcinbakrci
# User : elifnurkayalar
# Error : File b'data/clean/elifnurkayalar_cleaned.csv' does not exist
# User : OsamaSeyam92
# User : unveresra
# Error : File b'data/clean/unveresra_cleaned.csv' does not exist
# User : zulalucisik
# User : ersinoe
# User : msamilonder
# User : sofistiiike
# User : sseyma_z
# Error : File b'data/clean/sseyma_z_cleaned.csv' does not exist
# User : istnbulsehrunii
# Error : Cannot feed value of shape (0,) for Tensor 'Placeholder:0', which has shape '(?, 300)'
# User : YazanAlterkawi
# Error : Cannot feed value of shape (0,) for Tensor 'Placeholder:0', which has shape '(?, 300)'
# User : enesaltunbas
# User : gaziigiray
# Error : File b'data/clean/gaziigiray_cleaned.csv' does not exist
# User : zeynebtuf_
# Error : File b'data/clean/zeynebtuf__cleaned.csv' does not exist
# User : RatebAltal
# Error : Cannot feed value of shape (0,) for Tensor 'Placeholder:0', which has shape '(?, 300)'
# User : zottorihanzo
# User : RbCeylan
# Error : File b'data/clean/RbCeylan_cleaned.csv' does not exist
# User : MaadSharaf
# User : MehmetBurakDikm
# User : beytullahemrah
# Error : File b'data/clean/beytullahemrah_cleaned.csv' does not exist
# User : nsenaa
# User : otdergi
# User : alihankoca
# Error : File b'data/clean/alihankoca_cleaned.csv' does not exist
# User : Selmankurtulmus
# User : cay_hane
# User : dihizlan
# User : YusufSuphiTemel
# Error : File b'data/clean/YusufSuphiTemel_cleaned.csv' does not exist
# User : RtSehir
# User : y_eacar
# User : hatice_sari
# User : agcatamer
# User : aysepk
# User : ayselivermore
# User : SehirKonsey
# User : orhanguler1
# User : mervdgny
# User : OolcanPnr
# Error : File b'data/clean/OolcanPnr_cleaned.csv' does not exist
# User : TahaColakoglu
# User : senefii
# User : ragipsoylu
# User : FUATUGUR
# User : yigit_bozkurt
# User : Sevinnabi
# Error : File b'data/clean/Sevinnabi_cleaned.csv' does not exist
# User : asimoncel
# User : cagrikosak
# User : karataslymn
# Error : File b'data/clean/karataslymn_cleaned.csv' does not exist
# User : ahysnn
# User : nzheozyzicioglu
# User : SehirTarih
# User : sevdersoyy
# User : meryemyetkin
# Error : File b'data/clean/meryemyetkin_cleaned.csv' does not exist
# User : mahmutpancar
# User : erennhavlucu
# User : hilalerturk
# Error : File b'data/clean/hilalerturk_cleaned.csv' does not exist
# User : EsraUslupat
# Error : File b'data/clean/EsraUslupat_cleaned.csv' does not exist
# User : mbuyukmatur
# User : bfdellaloglu
# User : RealFirdaous
# User : zebiun
# Error : File b'data/clean/zebiun_cleaned.csv' does not exist
# User : SehirMuhKulubu
# User : Kajubey
# Error : File b'data/clean/Kajubey_cleaned.csv' does not exist
# User : theareveur
# Error : File b'data/clean/theareveur_cleaned.csv' does not exist
# User : malibuyukkara
# User : n/a
# User : khumeira
# User : direkciseyma
# User : HuseyinYayman
# User : sadadergisi
# User : _samiyigit
# Error : File b'data/clean/_samiyigit_cleaned.csv' does not exist
# User : n/a
# User : furkankinik
# User : nurundamla
# User : muhtaryasir
# Error : File b'data/clean/muhtaryasir_cleaned.csv' does not exist
# User : aferimcokguzel
# Error : File b'data/clean/aferimcokguzel_cleaned.csv' does not exist
# User : egurgoze
# User : tekhareketi
# User : essrup
# Error : File b'data/clean/essrup_cleaned.csv' does not exist
# User : yusufcos
# Error : File b'data/clean/yusufcos_cleaned.csv' does not exist
# User : dogukankotan
# Error : File b'data/clean/dogukankotan_cleaned.csv' does not exist
# User : zahitatcil
# User : cemilyavuzing
# User : surdangecti
# User : Politolog00
# User : emrahkayad
# User : manilkoc
# User : ozdemirrbusra
# Error : File b'data/clean/ozdemirrbusra_cleaned.csv' does not exist
# User : sivilses
# User : rukiaydin
# User : KabarBey_
# User : sehrinnotcusu
# User : yalcinari
# User : fatialtug
# User : sehirunigezi
# User : eliffuzell
# Error : File b'data/clean/eliffuzell_cleaned.csv' does not exist
# User : EdaKplan
# User : hilal_kaplan
# User : aatcil
# User : argosehir
# User : be__ce
# User : ibrahimutlu38
# User : ahdamar
# User : ErkamKARAKAYA
# User : alirizabsr
# User : sehomanya
# User : rumhfzoglu
# User : aysenurertem_
# User : melikdaye
# User : Sh4dett
# Error : File b'data/clean/Sh4dett_cleaned.csv' does not exist
# User : ahmetyesiltepe
# User : huzasim
# User : travissbickle
# User : eyado7
# User : alicnclk
# User : GulsahMrt
# User : furkntasar
# User : sehiruniv
# User : betulengin
# User : n/a
# User : ayenor
# User : AlajdinR
# Error : Cannot feed value of shape (0,) for Tensor 'Placeholder:0', which has shape '(?, 300)'
# User : yusufbayazit
# User : AbdullahTerzi_
# User : seydanlioglu
# User : Acaristaan
# Error : File b'data/clean/Acaristaan_cleaned.csv' does not exist
# User : inanamiyorumki
# User : MustafaUgurlu
# Error : File b'data/clean/MustafaUgurlu_cleaned.csv' does not exist
# User : satuskicha
# User : sehiruni118
# User : RobertDurst_
# User : sehirsanat
# User : kokonadespina
# User : elvina_gulverdi
# User : _rumeysaozturk
# User : mrtgokdemir
# User : ceydatatari
# Error : File b'data/clean/ceydatatari_cleaned.csv' does not exist
# User : mmalikinci
# Error : File b'data/clean/mmalikinci_cleaned.csv' does not exist
# User : adliforum
# User : bhicretyavuz
# User : fragileworldamn
# User : uzunyaylaagasi
# Error : File b'data/clean/uzunyaylaagasi_cleaned.csv' does not exist
# User : SNurSeker
# Error : File b'data/clean/SNurSeker_cleaned.csv' does not exist
# User : avci_feyza
# Error : File b'data/clean/avci_feyza_cleaned.csv' does not exist
# User : rumeysasenglu
# User : TUZBEDIRHAN
# User : ifurkantr
# User : meneserkan
# User : BEYTYZC
# User : mlsmelis96
# Error : File b'data/clean/mlsmelis96_cleaned.csv' does not exist
# User : osmoticpheno
# User : ALIATIFBIR
# User : mikrofonisehir
# User : AfA_1905
# Error : File b'data/clean/AfA_1905_cleaned.csv' does not exist
# User : ahmtbrkl
# User : busrasargin53
# User : zahsenk
# Error : File b'data/clean/zahsenk_cleaned.csv' does not exist
# User : seymaasahinn
# Error : File b'data/clean/seymaasahinn_cleaned.csv' does not exist
# User : tugbagayretli
# Error : File b'data/clean/tugbagayretli_cleaned.csv' does not exist
# User : sehirmusicclub
# User : Aliskaya
# User : 2el1firca
# User : humeyraseles
# Error : File b'data/clean/humeyraseles_cleaned.csv' does not exist
# User : mehmetmertkesti
# User : SehirGonullusu
# User : AyseSenaOkuyan
# User : harbisinema
# User : SCansuYaman
# Error : File b'data/clean/SCansuYaman_cleaned.csv' does not exist
# User : Birkantekin
# User : YavuzYigit
# User : SaitMahmut
# User : matmazeldedigin
# User : M_Ali_Caliskan
# User : cikorita_
# User : aaltundal7
# User : busraholmes
# Error : File b'data/clean/busraholmes_cleaned.csv' does not exist
# User : CetinkayaEgemen
# User : ZeynepSaracbasi
# Error : File b'data/clean/ZeynepSaracbasi_cleaned.csv' does not exist
# User : mkarabasoglu
# User : gulnihalli
# Error : File b'data/clean/gulnihalli_cleaned.csv' does not exist
# User : Seri_Reis
# User : Halimalbakkor
# User : muhendisimtirak
# User : karakaya_behlul
# User : muratyesiltas
# User : omerkacmen
# User : ebubekiryldzts
# Error : File b'data/clean/ebubekiryldzts_cleaned.csv' does not exist
# User : ilhantunahanbas
# User : DagtekinBilal
# User : elifdonmez
# User : ismailhakkihira
# Error : File b'data/clean/ismailhakkihira_cleaned.csv' does not exist
# User : ssibgatullahh
# User : tycitil
# User : detroitlikizil
# User : demiraysaliha
# User : sehirfest
# User : tunahanelmass
# User : daim_munzevii
# User : Abdul_shibli
# User : kelyazar
# User : busracicen
# User : JumailiAhmed
# User : Muleyke_B
# Error : File b'data/clean/Muleyke_B_cleaned.csv' does not exist
# User : orhansalihd
# Error : File b'data/clean/orhansalihd_cleaned.csv' does not exist
# User : mtozresch
# User : CHB_Avsadi
# User : klasikyayinlari
# User : byzkarahan
# Error : File b'data/clean/byzkarahan_cleaned.csv' does not exist
# User : ahmettarikeren
# User : ofarukcaliskan
# User : ozgulgeles
# User : jaefercan
# User : JamalSomaya
# Error : Cannot feed value of shape (0,) for Tensor 'Placeholder:0', which has shape '(?, 300)'
# User : ahmetcklc
# User : istdusevi
# User : azadesel
# User : kmlmstf25
# Error : File b'data/clean/kmlmstf25_cleaned.csv' does not exist
# User : ugrmtc
# User : lutfiyesevde
# User : msercanercan
# User : ysfsahan
# User : yiitche
# User : alperrrrrrrrr
# User : babelfishly
# User : hacertilbec
# User : busra_bulut
# User : McLolty
# Error : File b'data/clean/McLolty_cleaned.csv' does not exist
# User : teceeralp
# User : alpionel
# User : erkanshen
# User : egkceaksoy
# Error : File b'data/clean/egkceaksoy_cleaned.csv' does not exist
# User : eminilbeyli
# User : mazharbagli
# User : h_mustafaozel
# User : iamemrekaraman
# User : fnzehra
# User : sevdealtunn
# User : halitbekiroglu
# User : havvasula
# User : elifesrayvz
# User : isifsehir
# User : arslantaszeynep
# User : kkopuz
# User : nurpuytu
# Error : File b'data/clean/nurpuytu_cleaned.csv' does not exist
# User : kelemetcigdem
# User : muhammedalisit
# User : jenarcik
# User : nebimis
# User : taliasibai
# User : ferhatkentel
# User : yavuzluselim
# User : ErdemOkurFans
# User : FdnAli
# Error : Cannot feed value of shape (0,) for Tensor 'Placeholder:0', which has shape '(?, 300)'
# User : MalikShabanov
# User : hbaranf
# User : besterarslan
# Error : File b'data/clean/besterarslan_cleaned.csv' does not exist
# User : HEKVA_
# User : ssysfakb
# User : Allhass95
# Error : Cannot feed value of shape (0,) for Tensor 'Placeholder:0', which has shape '(?, 300)'
# User : sifanurhacer
# User : AliEminKrgz
# User : EbrarAydn5
# User : baskasi
# Error : File b'data/clean/baskasi_cleaned.csv' does not exist
# User : ISIKERFiliz
# User : burak_altun_
# User : tonoglumustafa
# Error : File b'data/clean/tonoglumustafa_cleaned.csv' does not exist
# User : hasipayanoglu
# User : omerfarukunver
# User : nesosyologu
# User : UsamErdogan
# User : efmertesacker
# User : sehirgezikulubu
# User : ofmoriste
# User : HalukDortluoglu
# User : AladagSaid
# Error : File b'data/clean/AladagSaid_cleaned.csv' does not exist
# User : ozerenbeyza
# User : eliffbanu
# User : Vaporjulep
# User : psikolojiktir
# User : maliustun
# User : zehratula
# User : hulyakdz
# User : EfekanBenlier
# User : moikinda
# User : gulsahmican
# User : behramkoca
# Error : File b'data/clean/behramkoca_cleaned.csv' does not exist
# User : mfurkanyavuz
# User : beyinsiz_adam
# User : abdkaraarslan
# User : makbuladimlar
# User : Candan_Dost
# User : _Biladerler
# User : msgonullu
# User : nottafound
# User : Falsemansfalse
# Error : File b'data/clean/Falsemansfalse_cleaned.csv' does not exist
# User : semssami
# User : orjinalinsan_
# User : hidirgevis
# User : husalptekin
# User : withheld_accnt
# User : istmcc
# User : EyupGokcee
# User : fdindarol
# User : isshhak
# User : tunakocaman
# User : ramazanodunccu
# User : KokchaZ
# Error : File b'data/clean/KokchaZ_cleaned.csv' does not exist
# User : baharalb
# Error : File b'data/clean/baharalb_cleaned.csv' does not exist
# User : ahsensurucu
# User : ibrahimizgi
# User : AAkkoyunn
# Error : File b'data/clean/AAkkoyunn_cleaned.csv' does not exist
# User : serraaltay
# User : sehirsosyal
# User : AhmetOztemz
# User : bsvmam
# User : YldzRamazanolu
# User : salihadiyaman
# User : islamsozler
# User : _____l_l_____
# User : MerdiQerechi
# Error : File b'data/clean/MerdiQerechi_cleaned.csv' does not exist
# User : Cihadinan
# User : lazamani
# User : kutluerilhan
# User : belizeee
# User : GokhanBicici
# User : HulkinAdami
# User : dikkenar
# User : Aysegulpayci
# User : _oteki_
# User : Korkut__Fatih
# User : umrangulbin
# Error : File b'data/clean/umrangulbin_cleaned.csv' does not exist
# User : matricariamilla
# Error : File b'data/clean/matricariamilla_cleaned.csv' does not exist
# User : mim_mfd
# User : sedatkucukbay
# User : sadecefm
# User : MeryemSuliman
# User : alperilealper
# Error : File b'data/clean/alperilealper_cleaned.csv' does not exist
# User : umit_aksoy
# User : birgariparaf
# User : odmanasli
# User : salimyavuz
# User : yunuzo
# User : SehirKariyer
# User : zemeuu
# User : eneskandur1
# User : bananbnbn
# User : safsatta
# User : TheAfrasiyab
# User : n/a
# User : gnageeb
# User : avcioral
# User : selimliyavuz
# User : IHalilUcer
# User : akfyksl
# Error : File b'data/clean/akfyksl_cleaned.csv' does not exist
# User : Cengizbeyza
# User : melis_hafez
# Error : File b'data/clean/melis_hafez_cleaned.csv' does not exist
# User : anbyildirim
# User : KlcDlara
# Error : File b'data/clean/KlcDlara_cleaned.csv' does not exist
# User : davettoplulugu
# User : FigenIlke
# User : safkanafkan
# User : SelimDemirkynk
# Error : File b'data/clean/SelimDemirkynk_cleaned.csv' does not exist
# User : senaadonmezz
# Error : File b'data/clean/senaadonmezz_cleaned.csv' does not exist
# User : goksukeserbi
# User : ZaferQassami
# User : arkakapak
# User : urbanhobbit
# User : balikgoz
# User : yasinTii
# User : ezraozsoy
# Error : File b'data/clean/ezraozsoy_cleaned.csv' does not exist
# User : n/a
# User : ramazancadiri
# User : hanifecatan
# Error : File b'data/clean/hanifecatan_cleaned.csv' does not exist
# User : _sedatulusoy
# User : mr_kaks1
# User : ofabiof
# User : ibrahmcikrikci
# Error : File b'data/clean/ibrahmcikrikci_cleaned.csv' does not exist
# User : Mazlumder_World
# User : aysenuryahsi
# User : salihecevit
# User : socsehir
# User : hakanbayrakk
# Error : File b'data/clean/hakanbayrakk_cleaned.csv' does not exist
# User : rektoratif
# Error : File b'data/clean/rektoratif_cleaned.csv' does not exist
# User : hramiustun
# User : snnogluberra
# Error : File b'data/clean/snnogluberra_cleaned.csv' does not exist
# User : ahmetkahveciler
# User : s_simityan
# User : erdemytt
# User : wafflecim
# User : hoposinanay
# User : carslan61
# Error : File b'data/clean/carslan61_cleaned.csv' does not exist
# User : asamiozen
# User : afsolmaz
# User : ayergisen
# User : fzcerci
# User : muakkib
# User : ohannes_klcdg
# User : suhedaduzcan
# Error : File b'data/clean/suhedaduzcan_cleaned.csv' does not exist
# User : okanncakarr1
# User : huseyingurbanov
# User : mufidyuksel
# User : sinanbolukoglu
# User : sehirdegisim
# User : ergulmhuseyin
# User : okurerdem
# User : yasemincakirer
# User : mzbalkas
# Error : File b'data/clean/mzbalkas_cleaned.csv' does not exist
# User : Zeina172
# User : aksubora
# User : KerimOZAL
# User : rumeysagecer
# User : GulnihalAydinli
# User : worldbulletin
# Error : Cannot feed value of shape (0,) for Tensor 'Placeholder:0', which has shape '(?, 300)'
# User : risusku
# User : sgrbll
# User : JournalSehir
# User : SehirCHES
# User : hiyenigun
# User : esrefisark
# User : nihaterdogmus
# User : hediyetullah_
# User : mhmtaytkn
# User : nurulu_
# Error : File b'data/clean/nurulu__cleaned.csv' does not exist
# User : bilalrdv
# User : haticeaynurr
# User : SafiyeSideli
# User : TemimHocaoglu
# User : sen_a_nur
# Error : File b'data/clean/sen_a_nur_cleaned.csv' does not exist
# User : ruhavi
# User : aakkgul
# User : usamevahap
# User : miailayda
# User : Bsrayrkcglu
# Error : File b'data/clean/Bsrayrkcglu_cleaned.csv' does not exist
# User : maligultekinn
# Error : File b'data/clean/maligultekinn_cleaned.csv' does not exist
# User : sukrukibar
# User : semanurkonuk_
# User : carullah_rumi
# Error : File b'data/clean/carullah_rumi_cleaned.csv' does not exist
# User : BekirZahid
# User : mertsaydogan
# Error : File b'data/clean/mertsaydogan_cleaned.csv' does not exist
# User : nbyerli
# Error : File b'data/clean/nbyerli_cleaned.csv' does not exist
# User : iReMCaNaNN
# User : reshadetimanov
# Error : File b'data/clean/reshadetimanov_cleaned.csv' does not exist
# User : seyharsanoy
# User : cakir_rusen
# User : esbeyazz
# Error : File b'data/clean/esbeyazz_cleaned.csv' does not exist
# User : senaadibeke
# User : zbakyildiz
# User : huzeyfeakkoyun
# User : YasinSaglam7
# Error : File b'data/clean/YasinSaglam7_cleaned.csv' does not exist
# User : ahofu
# User : talhaasil
# Error : File b'data/clean/talhaasil_cleaned.csv' does not exist
# User : esihatun
# User : nsugur
# User : mtalhakaan
# User : senerboztas
# User : sismanadam
# User : _elifcelebi
# User : Freuudd
# User : hakirim
# User : Mtn1907Snmz
# User : n/a
# User : ayasinoncu
# User : Talha_Kose1
# User : abadeeel
# User : SehirDance
# User : AliTahaYilki
# User : hilsehir
# User : zzahidec
# User : cerenkenar
# User : saidercan
# User : Mstfozl
# User : isamerIU
# User : sibeleraslan
# User : aylavkis
# Error : File b'data/clean/aylavkis_cleaned.csv' does not exist
# User : yzciyusuf
# User : MA_Sevinc
# User : tumsuz
# User : sehirliolmak
# User : konevim
# Error : File b'data/clean/konevim_cleaned.csv' does not exist
# User : _apoikia
# Error : File b'data/clean/_apoikia_cleaned.csv' does not exist
# User : sinoypexas
# Error : File b'data/clean/sinoypexas_cleaned.csv' does not exist
# User : azenginn
# Error : File b'data/clean/azenginn_cleaned.csv' does not exist
# User : ebuzercaliskan
# User : huseyintarik
# Error : File b'data/clean/huseyintarik_cleaned.csv' does not exist
# User : zeynebbus
# User : ZuhalCevahir
# Error : File b'data/clean/ZuhalCevahir_cleaned.csv' does not exist
# User : mnsaylik
# Error : File b'data/clean/mnsaylik_cleaned.csv' does not exist
# User : sehirkedileri
# User : yesimksknn
# Error : File b'data/clean/yesimksknn_cleaned.csv' does not exist
# User : yalcinn16
# User : feyzanr_tastkne
# User : abbassem
# User : berendaz
# User : tklhc
# Error : File b'data/clean/tklhc_cleaned.csv' does not exist
# User : sehirlibrary
# User : SGormezdengelme
# User : edanurbeyoglu
# User : nurbikhasta
# User : aytenkoldemir
# User : irosehir
# User : dino_baggiooo
# User : suigenerisloris
# User : bilen_hacer
# User : FurkanAkbal
# User : nibenka
# User : amerikabulteni
# User : besincimevsim
# Error : File b'data/clean/besincimevsim_cleaned.csv' does not exist
# User : Yahyayacoob
# Error : File b'data/clean/Yahyayacoob_cleaned.csv' does not exist
# User : uludagTayyip
# Error : File b'data/clean/uludagTayyip_cleaned.csv' does not exist
# User : N_Rsena
# Error : File b'data/clean/N_Rsena_cleaned.csv' does not exist
# User : NurullahArdic
# Error : File b'data/clean/NurullahArdic_cleaned.csv' does not exist
# User : cokmukomiksert
# User : cemalgunaydn
# User : emre_keskus
# User : zeynebsultan
# User : yusufelbasi
# User : suleyld
# User : Fikrsiz
# User : bsrdgc1
# User : tesnimozdinc
# Error : File b'data/clean/tesnimozdinc_cleaned.csv' does not exist
# User : banaelifde
# Error : File b'data/clean/banaelifde_cleaned.csv' does not exist
# User : lltoprak
# Error : File b'data/clean/lltoprak_cleaned.csv' does not exist
# User : beyjey
# Error : File b'data/clean/beyjey_cleaned.csv' does not exist
# User : surhewz
# User : ssewecen
# User : ozguralik
# User : BirKizBirOglan
# User : esoruc
# User : hamza_sis
# User : reyyanmunire
# User : huseyinikizoglu
# User : Sumeyra_Ozturk_
# User : ZenginGurkan
# User : mervesenel_
# Error : File b'data/clean/mervesenel__cleaned.csv' does not exist
# User : ibrahimcansu_
# Error : File b'data/clean/ibrahimcansu__cleaned.csv' does not exist
# User : bernottit
# Error : File b'data/clean/bernottit_cleaned.csv' does not exist
# User : kral
# User : RamadanTent
# Error : Cannot feed value of shape (0,) for Tensor 'Placeholder:0', which has shape '(?, 300)'
# User : ZeynepIlkkursun
# User : SehirHUKUK
# User : y_sarfati
# User : mrvaldg
# Error : File b'data/clean/mrvaldg_cleaned.csv' does not exist
# User : AlperenDuymus
# Error : File b'data/clean/AlperenDuymus_cleaned.csv' does not exist
# User : Aljalmoud
# User : mhmmdklss
# User : AliPulcu
# User : alihaliduslu
# User : sehircareerfest
# User : mustafazengins
# User : Kan3anio
# User : FZehraErcan
# User : makifmemmi
# User : gulucukgulucuk
# Error : File b'data/clean/gulucukgulucuk_cleaned.csv' does not exist
# User : akbaskevserr
# User : emervetekdemir
# Error : File b'data/clean/emervetekdemir_cleaned.csv' does not exist
# User : ayseguveli
# User : Sehir_Lab
# User : ebruaraci
# User : RbtKlk
# Error : File b'data/clean/RbtKlk_cleaned.csv' does not exist
# User : mrbozz
# Error : File b'data/clean/mrbozz_cleaned.csv' does not exist
# User : ezgcnbz
# Error : File b'data/clean/ezgcnbz_cleaned.csv' does not exist
# User : tufeyli_
# User : OGUZISMAILOGLU
# User : msmorkan
# User : msenel
# User : DivanDergisi
# User : simorgilas
# User : menescio647
# User : mrvoztrka
# Error : File b'data/clean/mrvoztrka_cleaned.csv' does not exist
# User : bbrkci_
# Error : File b'data/clean/bbrkci__cleaned.csv' does not exist
# User : Smeyyetemell
# User : betultastan
# User : ikbalarmagan
# User : sedadi
# User : mtahasamasti
# User : svmkirac
# Error : File b'data/clean/svmkirac_cleaned.csv' does not exist
# User : minval_
# User : ezgimermer
# Error : File b'data/clean/ezgimermer_cleaned.csv' does not exist
# User : andacmusa
# Error : File b'data/clean/andacmusa_cleaned.csv' does not exist
# User : melmetintas
# User : incubacity
# User : sehirliderlik
# User : hkosebalaban1
# Error : File b'data/clean/hkosebalaban1_cleaned.csv' does not exist
# User : AKSehirUni
# User : wwevergreen
# Error : File b'data/clean/wwevergreen_cleaned.csv' does not exist
# User : esranurkose
# User : alibazfatih
# User : TuncayHasibe
# Error : File b'data/clean/TuncayHasibe_cleaned.csv' does not exist
# User : idrissahinturk
# User : MhmtSlmz
# User : yamoonz
# Error : File b'data/clean/yamoonz_cleaned.csv' does not exist
# User : selimyaman_
# User : label
# Error : Cannot feed value of shape (0,) for Tensor 'Placeholder:0', which has shape '(?, 300)'
# User : turhanays
# Error : File b'data/clean/turhanays_cleaned.csv' does not exist
# User : ramazanaras
# User : muratkucukvar
# User : enes_avar
# User : NeslihanTezcn
# Error : File b'data/clean/NeslihanTezcn_cleaned.csv' does not exist
# User : cavusunhace
# User : alpersoyupak
# Error : File b'data/clean/alpersoyupak_cleaned.csv' does not exist
# User : aysnresr
# Error : File b'data/clean/aysnresr_cleaned.csv' does not exist
# User : DKose__
# User : nessyys
# User : darisaadetsehir
# User : zddemir_
# User : avmbalci
# User : msapaydin
# User : ZeyneepSinan
# Error : File b'data/clean/ZeyneepSinan_cleaned.csv' does not exist
# User : DablanMayasa
# Error : Cannot feed value of shape (0,) for Tensor 'Placeholder:0', which has shape '(?, 300)'
# User : zfeyza
# Error : File b'data/clean/zfeyza_cleaned.csv' does not exist
# User : soceylul
# Error : File b'data/clean/soceylul_cleaned.csv' does not exist
# User : reyta_akdeniz
# Error : Cannot feed value of shape (0,) for Tensor 'Placeholder:0', which has shape '(?, 300)'
# User : mudahilpachi
# User : latffest
# User : mustafasenbd
# User : sedatlaciner
# User : yurtalan92
# Error : File b'data/clean/yurtalan92_cleaned.csv' does not exist
# User : mihmandarbyztpz
# User : BelksKlkaya
# User : zynpaslihn
# Error : File b'data/clean/zynpaslihn_cleaned.csv' does not exist
# User : unfabulousdt_
# Error : File b'data/clean/unfabulousdt__cleaned.csv' does not exist
# User : aozturk1
# Error : File b'data/clean/aozturk1_cleaned.csv' does not exist
# User : tugtagelif
# User : m_colak_
# User : sehirkadem
# User : betullcolak
# User : isifkulubu
# User : EsadGokdemir
# User : filizkayann
# User : Sam_Al_Ghammari
# User : kuche_rindan
# User : profdralikose
# User : fzfz53
# User : sehir14
# User : n/a
# User : mrvebayram
# Error : File b'data/clean/mrvebayram_cleaned.csv' does not exist
# User : malcolmiye
# User : uguryunus
# User : ibrahimusaonder
# User : mskdmrbsr
# User : mdaliaydin
# Error : File b'data/clean/mdaliaydin_cleaned.csv' does not exist
# User : OmerFatsa
# User : NilsuKYN
# Error : File b'data/clean/NilsuKYN_cleaned.csv' does not exist
# User : eylulco
# Error : File b'data/clean/eylulco_cleaned.csv' does not exist
# User : azrafsin
# User : emrahakbas
# User : suhedaaricii
# User : salihdogan_
# User : Zarella92
# Error : File b'data/clean/Zarella92_cleaned.csv' does not exist
# User : SevdeKurt
# User : 34DRU94
# User : aybukeyazici
# User : BetulAkova
# Error : File b'data/clean/BetulAkova_cleaned.csv' does not exist
# User : elifdolapcioglu
# User : 2kita1mutluluk
# User : sehirunisikayet
# User : farukozcetin
# User : sehirpolitika
# User : serdarbs
# User : kirkolesi
# User : shybrdmci
# User : alev_erkilet
# User : mselimkarsli
# Error : File b'data/clean/mselimkarsli_cleaned.csv' does not exist
# User : ebrausta
# Error : File b'data/clean/ebrausta_cleaned.csv' does not exist
# User : maydemir1001
# User : fdemirci
# User : drkerem
# User : Melodia_B
# Error : File b'data/clean/Melodia_B_cleaned.csv' does not exist
# User : Alwaysprep
# User : anatolianirfan
# User : zeynpylmaz
# User : _yakebikec
# User : yinemizeze
# User : sehirmgtclub
# User : bilalhorasan
# User : HusniyeKoc
# Error : File b'data/clean/HusniyeKoc_cleaned.csv' does not exist
# User : kdrtemiz
# User : YavuzSelimKol
# User : SehirDragos
# User : Firattalha
# User : ofkocum
# User : ozgurcelaleddin
# User : Bahaksit
# Error : File b'data/clean/Bahaksit_cleaned.csv' does not exist
# User : cizikplak
# User : DilaraDemir3
# User : SehirGirisim
# User : HazalTurhan
# User : MYasirOkumus
# User : qbitclub
# User : MerveMuzmul
# User : abalci
# User : enisberkc
# User : VildanKadioglu
# Error : File b'data/clean/VildanKadioglu_cleaned.csv' does not exist
# User : furkancakmak
# Error : File b'data/clean/furkancakmak_cleaned.csv' does not exist
# User : eeslems
# User : korfoula_
# User : RanaGulnihal
# User : sehrifotograf
# User : Simurger
# User : Afurkanakbulut
# User : n/a
# User : furkanysr
# User : olafaybk
# User : Seyyidesifa_
# Error : File b'data/clean/Seyyidesifa__cleaned.csv' does not exist
# User : hortumcuzk
# User : itaatsiz
# User : sehirmed
# User : esadunal
# Error : File b'data/clean/esadunal_cleaned.csv' does not exist
# User : RanaKurt
# User : aysenuryurttas
# Error : File b'data/clean/aysenuryurttas_cleaned.csv' does not exist
# User : gkhngol
# User : ergul_aysenur
# Error : File b'data/clean/ergul_aysenur_cleaned.csv' does not exist
# User : kamilardaelif
# User : _hepyek
# Error : File b'data/clean/_hepyek_cleaned.csv' does not exist
# User : sehiratolye
# User : abdulaziztalha
# User : muhammed_hasan
# Error : Cannot feed value of shape (0,) for Tensor 'Placeholder:0', which has shape '(?, 300)'
# User : hayallervarya
# User : ErturkMahmud
# User : yunusdemir1453
# User : onurguzey
# User : SernurY
# User : EleyanMe
# Error : File b'data/clean/EleyanMe_cleaned.csv' does not exist
# User : dilsizdilci
# User : n/a
# User : ahmetabdallah
# User : seyma_topcu
# User : hby34
# User : tugrulbakir
# User : gencmots
# User : vlldn
# Error : File b'data/clean/vlldn_cleaned.csv' does not exist
# User : kinlikleri
# User : guruntu
# User : ahmetfarukeker
# User : bnoktadino
# User : ozdagsemihaa
# User : kamilturan_
# User : parmakuclari
# User : fatma_denizz
# Error : File b'data/clean/fatma_denizz_cleaned.csv' does not exist
# User : meliketuloglu
# User : arasbulent
# User : myasiny13
# User : zubyde_melek
# User : tarcinlielmali
# User : Seda_Ozen
# User : AybikeUluc
# User : MustafaOzelden
# User : MCanErim
# User : myilmaz_67
# User : Quce_gezen
# User : karamzalininki
# User : osmansrt
# User : bahadirbektas61
# User : a_enesozel
# User : esraakbulak____
# User : BehlulOzkan
# User : smlerkam
# Error : File b'data/clean/smlerkam_cleaned.csv' does not exist
# User : muhammedtoprak
# User : DelikayaSinan
# User : sadecekisi
# User : NursenaOzcan
# Error : File b'data/clean/NursenaOzcan_cleaned.csv' does not exist
# User : cengizkallek
# User : tuncaykardas
# Error : File b'data/clean/tuncaykardas_cleaned.csv' does not exist
# User : Beyza_nuur
# User : negahkon
# Error : File b'data/clean/negahkon_cleaned.csv' does not exist
# User : senerakturk
# User : sevgiblgc
# Error : File b'data/clean/sevgiblgc_cleaned.csv' does not exist
# User : harabatkahve
# User : STkariyer
# User : celileco
# User : atsekc
# Error : File b'data/clean/atsekc_cleaned.csv' does not exist
# User : granieve
# User : ZubeyirNisanci
# User : gamdefterdari
# Error : File b'data/clean/gamdefterdari_cleaned.csv' does not exist
# User : entelmilitan
# User : seymaberberoglu
# User : aybein
# Error : File b'data/clean/aybein_cleaned.csv' does not exist
# User : AlaaAlChalabi
# User : YzeydanK
# User : abdussamedtkdmr
# Error : File b'data/clean/abdussamedtkdmr_cleaned.csv' does not exist
# User : rnur_
# User : zry_kr
# Error : File b'data/clean/zry_kr_cleaned.csv' does not exist
# User : mazrub
# Error : File b'data/clean/mazrub_cleaned.csv' does not exist
# User : Zaaaino
# Error : File b'data/clean/Zaaaino_cleaned.csv' does not exist
# User : MelihTalu
# Error : File b'data/clean/MelihTalu_cleaned.csv' does not exist
# User : MamdoohDayem
# Error : Cannot feed value of shape (0,) for Tensor 'Placeholder:0', which has shape '(?, 300)'
# User : EDmlpnr
# User : AEskilerr
# User : sehirdiplomasi
# User : Ycaliska10
# User : iremtatlidedee
# Error : File b'data/clean/iremtatlidedee_cleaned.csv' does not exist
# User : mmeryemcee
# Error : File b'data/clean/mmeryemcee_cleaned.csv' does not exist
# User : ergun_hanife
# User : ozlem_albayrak
# Error : File b'data/clean/ozlem_albayrak_cleaned.csv' does not exist
# User : msumeyyekaraca
# Error : File b'data/clean/msumeyyekaraca_cleaned.csv' does not exist
# User : yekarahan
# User : mucahitkyilmaz
# User : hacerkor
# User : cetinsayag
# User : fatimatubapetek
# User : sadikunay
# User : bugrahantanir
# Error : File b'data/clean/bugrahantanir_cleaned.csv' does not exist
# User : tzachint
# Error : File b'data/clean/tzachint_cleaned.csv' does not exist
# User : maddy_sb94
# Error : Cannot feed value of shape (0,) for Tensor 'Placeholder:0', which has shape '(?, 300)'
# User : fusariyasar
# User : serhatacikel
# Error : File b'data/clean/serhatacikel_cleaned.csv' does not exist
# User : burcu_saglam
# User : algahafy
# Error : File b'data/clean/algahafy_cleaned.csv' does not exist
# User : kayyum1905
# User : rabiaozkn06
# User : FerdanErgut
# User : KayaOzlemm
# User : BisavTAM
# User : YildirimEbr
# Error : File b'data/clean/YildirimEbr_cleaned.csv' does not exist
# User : Aliyasar93
# User : ranaekinzi
# User : kkaraca53
# User : osmanoguzhan18
# Error : File b'data/clean/osmanoguzhan18_cleaned.csv' does not exist
# User : gokcetal
# User : taalluq
# User : ayan_talha
# User : n/a
# User : cezeyde
# User : ReyyanBilge
# User : s_yuksell
# User : eltgun
# User : poetikkliseler
# Error : File b'data/clean/poetikkliseler_cleaned.csv' does not exist
# User : yldrm_rumm
# User : mensurakgun
# User : myavuzkanar
# Error : File b'data/clean/myavuzkanar_cleaned.csv' does not exist
# User : n/a
# User : bordeauxrot
# User : n/a
# User : omerfarugyilmaz
# User : mngokalp
# User : eneseryarsoy
# User : MDodurgali
# Error : File b'data/clean/MDodurgali_cleaned.csv' does not exist
# User : nincinsan
# User : iyilikhane
# User : bcansiz61
# User : KerimPlstr
# Error : File b'data/clean/KerimPlstr_cleaned.csv' does not exist
# User : void_ab_initio
# User : ayvz25
# User : billirem
# User : seuraloglu
# User : mahmuthakin
# User : mehmettalpaslan
# User : SosyolojiDukkan
# User : omerfarukyagc7
# User : nalperuslu
# User : AHamitYilmaz
# User : dunya20101
# User : gulsalihh
# User : ertanaydin
# User : aliselmanaydin
# Error : File b'data/clean/aliselmanaydin_cleaned.csv' does not exist
# User : kaancomert4
# Error : File b'data/clean/kaancomert4_cleaned.csv' does not exist
# User : KodlamaAtolyesi
# User : sehir_alumni
# User : zeeynepp__
# Error : File b'data/clean/zeeynepp___cleaned.csv' does not exist
# User : peyamicelikcan
# User : GalipDalay
# User : cefasehirfm
# User : memetali_guveli
# User : sehir_cs
# User : RyhnDnc
# User : BengisuAkkurt
# User : pavlovunessegi
# User : nurozturk
# Error : File b'data/clean/nurozturk_cleaned.csv' does not exist
# User : SamimAkgonul
# User : tekerlekustu
# User : tuhafsakal
# Error : File b'data/clean/tuhafsakal_cleaned.csv' does not exist
# User : gizlikitaplik
# User : TEKurtulmus
# User : namesrunesne
# User : mrvarmagan
# User : sehir_munazara
# User : tahailbk
# User : beyzaaticii
# User : eluvarii
# User : fakirekucuk
# User : _MehmetOzkan
# User : ieeesehir
# User : sabvambuco
# User : GuneriSare
# User : Mevlanaidris
# User : AtaseverYasemin
# User : sancaktarmerve
# User : Bernagundogmus
# User : AzraSancak
# User : byekose
# User : sedanuruygun
# Error : File b'data/clean/sedanuruygun_cleaned.csv' does not exist
# User : elifgulceyavuz
# User : esmaduuman
# User : michealbonus
# Error : File b'data/clean/michealbonus_cleaned.csv' does not exist
# User : Levent
# User : SonmezDilruba
# User : halimekokce
# User : sehirgastronomi
# User : neziherdogan
# User : ahmetsahin23
# User : nebiye_0
# User : esad_ergen
# Error : File b'data/clean/esad_ergen_cleaned.csv' does not exist
# User : GulKabadayi
# Error : File b'data/clean/GulKabadayi_cleaned.csv' does not exist
# User : parafe08
# Error : File b'data/clean/parafe08_cleaned.csv' does not exist
# User : rumeysaabayram
# Error : File b'data/clean/rumeysaabayram_cleaned.csv' does not exist
# User : takipedicibirer
# User : MahmudEmini
# User : tubabst
# User : jebihemta
# User : EAfat
# User : 1001kelime
# User : suheylcakar
# Error : File b'data/clean/suheylcakar_cleaned.csv' does not exist
# User : tyasinnkaya
# User : roberkoptas
# User : handeesezgin
# User : eveline__0
# Error : File b'data/clean/eveline__0_cleaned.csv' does not exist
# User : photography__ms
# Error : File b'data/clean/photography__ms_cleaned.csv' does not exist
# User : _Mustafa_C_
# User : yasaremreyunus
# User : luciasc20903469
# User : hllbusracbc
# User : kulupkulturel
# User : hatip_ismail
# User : yasirdnmz
# User : AtakanYasak
# User : Metin4020
# User : skagankose
# User : dunyaninresmi
# User : kumsalgokalp
# User : cahidezeynep
# User : bekirgur
# User : Mustafa_Dmry
# User : iremtutuncu
# User : monografjournal
# User : gokseyircisi
# Error : File b'data/clean/gokseyircisi_cleaned.csv' does not exist
# User : nedesemeskidi
# User : nuruayri
# User : Kajunlimited
# Error : File b'data/clean/Kajunlimited_cleaned.csv' does not exist
# User : Mhmt_Fth
# User : yinebirgulnihal
# User : serkanhb
# User : omerfarukkahve
# User : Abdowski
# User : fatihayt3kin
# User : whitechomocha
# Error : File b'data/clean/whitechomocha_cleaned.csv' does not exist
# User : siyasetotagi
# User : anisatahiri
# Error : File b'data/clean/anisatahiri_cleaned.csv' does not exist
# User : mfkeles
# User : mervelifk
# User : sehir_fm
# User : smyykc
# User : msaidergun
# User : SehirFMFilm
# User : fatmakoktas
# Error : Cannot feed value of shape (0,) for Tensor 'Placeholder:0', which has shape '(?, 300)'
# User : tugceileri63
# Error : File b'data/clean/tugceileri63_cleaned.csv' does not exist
# User : n/a
# User : Baksakal
# User : hasan_karasu
# User : Bngbsbdk
# Error : File b'data/clean/Bngbsbdk_cleaned.csv' does not exist
# User : ayse11397
# Error : File b'data/clean/ayse11397_cleaned.csv' does not exist
# User : merken34
# User : mtozyayla
# User : yusufziyakocc
# User : tvfkmlhertzn
# User : Nidaaksoy
# Error : File b'data/clean/Nidaaksoy_cleaned.csv' does not exist
# User : calperk
# Error : File b'data/clean/calperk_cleaned.csv' does not exist
# User : smeyrayavuz4
# User : 1maviruh1
# User : SinemAtlgan
# Error : File b'data/clean/SinemAtlgan_cleaned.csv' does not exist
# User : eksi_zeytin
# User : idrismahfi
# User : HumeyraTpz
# User : beratozipek
# User : BilalAkbasoglu
# User : akca_toplulugu
# User : sehirggk
# User : n/a
# User : _katrunneda_
# Error : File b'data/clean/_katrunneda__cleaned.csv' does not exist
# User : baraclimelih
# Error : File b'data/clean/baraclimelih_cleaned.csv' does not exist
# User : zulfikar___
# User : ebrarkeser
# User : sumeyrayvz6
# User : tubaamagile
# Error : File b'data/clean/tubaamagile_cleaned.csv' does not exist
# User : zeynep_erdim
# User : haykallmuhammad
# User : HallaBarakat
# Error : Cannot feed value of shape (0,) for Tensor 'Placeholder:0', which has shape '(?, 300)'
# User : cozumsirkesi
# User : izakyol
# User : hanneballi
# User : Fissalalsharef
# User : mfatihaysan
# User : YTahaSagir
# Error : File b'data/clean/YTahaSagir_cleaned.csv' does not exist
# User : Ahmet66yldz
# User : msbslmz
# Error : File b'data/clean/msbslmz_cleaned.csv' does not exist
# User : hburakeyupoglu
# User : silatrkn
# User : dideesu
# User : kidlion093
# User : MechanicsArGe
# User : oluradionun
# User : sehiranemo
# User : SEHIRGENCTEMA
# User : SehirDreamers
# User : EmsalAtes
# User : yasarogluelif
# User : slnzrl
# User : ayylakogrenci
# User : abbilidi
# User : iremnurozdilek
# User : ayca_cu
# User : altunbekk
# User : SehirCTV
# User : ondermy
# User : atillatayyar
# Error : File b'data/clean/atillatayyar_cleaned.csv' does not exist
# User : zencidervis
# User : Ayaaldakkak
# User : CanHamza
# User : cebeliarici
# Error : File b'data/clean/cebeliarici_cleaned.csv' does not exist
# User : muratsenturke
# User : turgayogur
# User : SehirUniversite
# User : sosyolock
# User : salihaltundal
# Error : File b'data/clean/salihaltundal_cleaned.csv' does not exist
# User : Altuntasefe
# User : CuneytAykac
# User : SehirMYO
# User : dmrserra
# User : kivircik1adam
# User : AliBaveer
# User : emrekayaci2
# User : aferinlan
# Error : File b'data/clean/aferinlan_cleaned.csv' does not exist
# User : r4biaplatform
# User : hatice_sozeri
# User : hizcarpizaman
# User : BSVKAM
# User : zchouroro
# Error : File b'data/clean/zchouroro_cleaned.csv' does not exist
# User : ayhankucuk61
# User : nihashilas
# User : EnsSvmli
# User : yerlesikgocmen
# User : SudeBeyaz_
# User : UlugBaha
# User : ozdincmehmet
# User : yildarado
# User : uhuzak
# User : Sir_Obra
# Error : File b'data/clean/Sir_Obra_cleaned.csv' does not exist
# User : AhmetSToprak
# User : sumeyrayerinde
# User : DmrSmyy
# User : knhac
# User : EmreMetinin
# User : elifdevelii
# User : saidkocaa
# User : krmbzds
# Error : File b'data/clean/krmbzds_cleaned.csv' does not exist
# User : sehiredebiyat
# User : yusufkahyaa
# User : ayhanbilgen
# User : OuzhanErdem
# Error : File b'data/clean/OuzhanErdem_cleaned.csv' does not exist
# User : mr_karabag
# User : umitcizre
# User : Nbanup
# User : ahmet_ademoglu
# User : awesomephysicst
# Error : Cannot feed value of shape (0,) for Tensor 'Placeholder:0', which has shape '(?, 300)'
# User : ozgegenc
# User : sumeyyearisoy
# Error : File b'data/clean/sumeyyearisoy_cleaned.csv' does not exist
# User : SehirCC
# Error : File b'data/clean/SehirCC_cleaned.csv' does not exist
# User : SefureDO
# User : meldademoglu
# User : alimuratyel
# User : tugbabayraktaro
# User : YalcinArmagn
# Error : File b'data/clean/YalcinArmagn_cleaned.csv' does not exist
# User : EkmekciFaruk
# User : gulaykaplan
# Error : File b'data/clean/gulaykaplan_cleaned.csv' does not exist

# %%
inputFile.close()
outputFile.close()

# %% [markdown]
# ## Writing texts to train LSTM

# %%
inputFile = open('data/graph/node.csv', 'rt')
reader = csv.reader(inputFile)

# %%
politicsList = list()
artList = list()
dailyList = list()
charityList = list()

for line in reader:
    userName = line[2]
    
    if userName != "n/a":
        try: 
            # Load user tweets and assign a label to each of them
            currentDataframe = pd.read_csv("data/clean/" + userName + '_cleaned.csv', sep=',', header=None, names=["label","tweets"])
            currentTweets = currentDataframe['tweets'].values
            currentBagOfWordsMatrix = bagOfWords(currentTweets, fasttextModel, 300)
            predictedLabels = session.run(probabilityLabels, feed_dict={x:currentBagOfWordsMatrix})

            # Calculate frequency of labels
            labelCount = {"politics":0, "art":0, "society":0, "charity":0}
            for prediction in predictedLabels:
                if prediction == 0:
                    labelCount['politics'] += 1
                elif prediction == 1:
                    labelCount['art'] += 1
                elif prediction == 2:
                    labelCount['society'] += 1
                elif prediction == 3:
                    labelCount['charity'] += 1

            total = float(len(currentDataframe))
            interestDictionary = {key: value / total for key, value in labelCount.items()}
            mainInterest = max(interestDictionary.items(), key=operator.itemgetter(1))[0]
            
            if mainInterest == "politics":
                politicsList.append(int(line[1]))
            elif mainInterest == "art":
                artList.append(int(line[1]))
            elif mainInterest == "society":
                dailyList.append(int(line[1]))
            elif mainInterest == "charity":
                charityList.append(int(line[1]))  
            print("Success : %s" % userName)

        except Exception as error:
            print("Error : %s for %s" % (error, userName))
        
politicsList = set(politicssList)
artList = set(arttList)
dailyList = set(dailyList)
charityList = set(charityList)
# Out:
# Error : File b'data/clean/alicankanoglu_cleaned.csv' does not exist for alicankanoglu
# Success : sehir_edebiyat
# Error : File b'data/clean/handetuzlakoglu_cleaned.csv' does not exist for handetuzlakoglu
# Error : File b'data/clean/safakmhmt_cleaned.csv' does not exist for safakmhmt
# Success : furkanemer43
# Error : File b'data/clean/psikologvari_cleaned.csv' does not exist for psikologvari
# Success : Beyanor
# Error : File b'data/clean/rkahrmn_cleaned.csv' does not exist for rkahrmn
# Error : File b'data/clean/SivilSehirli_cleaned.csv' does not exist for SivilSehirli
# Success : zeynephepi
# Success : DemirlerinYavuz
# Success : necmettinndogan
# Success : philobuny
# Success : sabankardas
# Success : ahmet_ors
# Success : htcugurist
# Success : Marmaraaa
# Success : Donoughtella
# Error : File b'data/clean/usamedegirmenci_cleaned.csv' does not exist for usamedegirmenci
# Success : SehirClubs
# Error : File b'data/clean/ozhanneslihan_cleaned.csv' does not exist for ozhanneslihan
# Success : bvuslatcelik
# Success : zepaltinbas
# Success : mhmmtmz
# Success : ssuheyl
# Error : File b'data/clean/zeynepkoyuncu__cleaned.csv' does not exist for zeynepkoyuncu_
# Error : File b'data/clean/di__rapunzel_cleaned.csv' does not exist for di__rapunzel
# Success : glcnavsar
# Success : burakincecik
# Success : sosyalbilimler
# Success : BabaOnurbaba02
# Success : TSAorgtr
# Success : sehirKIZILAY
# Success : burhanduran
# Success : NurOzyayla
# Success : sehirgundemi
# Error : Cannot feed value of shape (0,) for Tensor 'Placeholder:0', which has shape '(?, 300)' for turanmeryemm
# Success : kulturistan
# Success : mefuslu
# Success : farukagrali
# Success : diaspora_turk
# Success : bubirisaret
# Success : cetinkoc
# Success : dunyabizim
# Success : enesogIu
# Success : ustkatsakini
# Error : File b'data/clean/mutlutarih_cleaned.csv' does not exist for mutlutarih
# Success : Hsyn_Uynk
# Success : Sehir_Law
# Success : ihsanelhan
# Success : FeyyazDerinoglu
# Success : Directoroyun
# Error : File b'data/clean/smyyakgul_cleaned.csv' does not exist for smyyakgul
# Error : Cannot feed value of shape (0,) for Tensor 'Placeholder:0', which has shape '(?, 300)' for sfsckesc
# Success : Haluket
# Success : Nocryletstry
# Success : serhatnasiroglu
# Success : beyzanurkocak_
# Error : File b'data/clean/m_emreaydin_cleaned.csv' does not exist for m_emreaydin
# Success : zuhalnurbanu
# Success : gulsumkavuncu
# Success : aeser_
# Success : universiteprog
# Success : ilkebu
# Error : File b'data/clean/Twltter56480961_cleaned.csv' does not exist for Twltter56480961
# Success : Jllykss
# Success : yensaroglu
# Success : rbcebeci
# Success : at_abisi
# Success : MohsawThe
# Success : saruhanoguzhan
# Success : MurekkepDusunce
# Success : DumbDuckkk
# Success : ensargul
# Success : opsesiff
# Success : amnaalellam
# Success : sharno3
# Success : frkntemiz
# Success : mcs1597
# Error : File b'data/clean/EnesEtlik_cleaned.csv' does not exist for EnesEtlik
# Success : OzSehirP
# Success : hsnasdfghj
# Success : mervecban
# Success : akyollahmet
# Success : NoliUla
# Success : kplnabdullahh
# Success : SerdarSanlier
# Success : ebrukayaalp
# Error : File b'data/clean/SehirCycling_cleaned.csv' does not exist for SehirCycling
# Success : zenubya_
# Success : halemek
# Error : File b'data/clean/ArtanKubra_cleaned.csv' does not exist for ArtanKubra
# Error : File b'data/clean/cumartesiannesi_cleaned.csv' does not exist for cumartesiannesi
# Success : abo_bery
# Success : muhittinEozkan
# Error : File b'data/clean/iphilocalist_cleaned.csv' does not exist for iphilocalist
# Success : kardelen62
# Error : File b'data/clean/ayehalhali_cleaned.csv' does not exist for ayehalhali
# Error : File b'data/clean/gaziiseker_cleaned.csv' does not exist for gaziiseker
# Error : Cannot feed value of shape (0,) for Tensor 'Placeholder:0', which has shape '(?, 300)' for TahirAbbas_
# Success : SuheylUtku
# Success : ikalin1
# Success : dilmencern
# Error : File b'data/clean/feyzagoksu__cleaned.csv' does not exist for feyzagoksu_
# Success : tokfirdevs
# Error : File b'data/clean/ikibarr_cleaned.csv' does not exist for ikibarr
# Error : File b'data/clean/gastesehir_cleaned.csv' does not exist for gastesehir
# Success : sehirmot
# Error : File b'data/clean/mmurataydemir_cleaned.csv' does not exist for mmurataydemir
# Success : yasakMIS
# Success : DenizBaran_db
# Success : SamSehir
# Error : File b'data/clean/omerclb_cleaned.csv' does not exist for omerclb
# Success : yrtsvrezgi
# Error : File b'data/clean/MuhittinAtaman_cleaned.csv' does not exist for MuhittinAtaman
# Success : serimcetin
# Success : Hllibrahim
# Success : tarik_tufan
# Success : Sehir_Kutuphane
# Success : ahmetcemiman
# Success : Ahmetaydiiin
# Success : AdaletZemini
# Error : File b'data/clean/uniquetekkk_cleaned.csv' does not exist for uniquetekkk
# Success : aysealtinay
# Success : ameleNotik
# Success : Samlikizi
# Error : File b'data/clean/yilmazusakli_cleaned.csv' does not exist for yilmazusakli
# Success : batm3nn
# Success : ysfzygokcek
# Success : Cediddi
# Success : OttomanArchive
# Error : File b'data/clean/halilibrahimltr_cleaned.csv' does not exist for halilibrahimltr
# Success : emregurlerr
# Success : aslitelli
# Error : File b'data/clean/ahmetkusol_cleaned.csv' does not exist for ahmetkusol
# Success : mesutyegen
# Success : eminesumeyra
# Success : birisine1soz
# Success : Makbuluttt
# Success : hamzalbayrak
# Success : fmervekeskin
# Success : hikmetogutgen
# Error : File b'data/clean/syukaripinar_cleaned.csv' does not exist for syukaripinar
# Success : HesetBrahimi
# Error : File b'data/clean/ahsenbusra_cleaned.csv' does not exist for ahsenbusra
# Success : SehirFelsefe
# Success : celilcivan
# Success : AlibediRzr
# Error : Cannot feed value of shape (0,) for Tensor 'Placeholder:0', which has shape '(?, 300)' for o_salha
# Success : AhmetSelim61
# Success : senadarici
# Success : hakkiuygur1
# Error : File b'data/clean/fundaozerrr_cleaned.csv' does not exist for fundaozerrr
# Success : OmerFarukKafali
# Success : furkangencer
# Success : hilalkoseee
# Success : sehirpsychclub
# Success : ceylaneb
# Error : File b'data/clean/ebrugun3s_cleaned.csv' does not exist for ebrugun3s
# Success : A_Boynukalin
# Success : helebilo
# Error : File b'data/clean/ozturkji_cleaned.csv' does not exist for ozturkji
# Success : rmznklc2
# Error : File b'data/clean/sedanuraslaner_cleaned.csv' does not exist for sedanuraslaner
# Error : File b'data/clean/PakerMurat_cleaned.csv' does not exist for PakerMurat
# Error : File b'data/clean/emreteke27_cleaned.csv' does not exist for emreteke27
# Success : drbetulsayan
# Success : rabiaedibe
# Error : File b'data/clean/smrarslan_cleaned.csv' does not exist for smrarslan
# Success : mesutyilmaz61
# Success : plavileptirr
# Success : Muharremdir
# Success : Bilalisgoren
# Success : tugbatekerek
# Success : GeziSehir
# Error : Cannot feed value of shape (0,) for Tensor 'Placeholder:0', which has shape '(?, 300)' for etkaiscan
# Error : File b'data/clean/uluslaras_cleaned.csv' does not exist for uluslaras
# Success : bunyaminbezci
# Success : psikologhanem
# Success : stlkahve6
# Success : yunusalierol
# Success : bmeteoglu
# Error : File b'data/clean/Sibai_Homs_cleaned.csv' does not exist for Sibai_Homs
# Error : File b'data/clean/eshylkaratas_cleaned.csv' does not exist for eshylkaratas
# Error : File b'data/clean/evrenmenguc_cleaned.csv' does not exist for evrenmenguc
# Success : nisanurhekim
# Success : nidarslanbaba
# Error : File b'data/clean/ehuntres_cleaned.csv' does not exist for ehuntres
# Success : filozofefendi
# Error : File b'data/clean/burrcylmz_cleaned.csv' does not exist for burrcylmz
# Success : onaildogan
# Success : selineknci
# Error : File b'data/clean/muharremkilic1_cleaned.csv' does not exist for muharremkilic1
# Success : denizilhan
# Error : File b'data/clean/osman7e_cleaned.csv' does not exist for osman7e
# Success : Leyla_Ipekci
# Error : File b'data/clean/EnesBasarir_cleaned.csv' does not exist for EnesBasarir
# Success : abenesay
# Error : File b'data/clean/ashurehatun_cleaned.csv' does not exist for ashurehatun
# Success : tlhclk
# Success : acansezgin
# Success : dilaradoganer1
# Success : Evreki
# Success : emintopkaraoglu
# Error : File b'data/clean/SumeyyeI_cleaned.csv' does not exist for SumeyyeI
# Success : alimarli_
# Success : tkucukcan
# Success : ElaAltinay
# Success : muminbahlol
# Success : ebulferec34
# Success : iclalkirman
# Error : File b'data/clean/elfltn_cleaned.csv' does not exist for elfltn
# Error : File b'data/clean/nuraaksu_cleaned.csv' does not exist for nuraaksu
# Success : burhankoroglu
# Success : f_betul_a
# Success : hudaverdiyim
# Success : yumnabike
# Success : sehircayhane
# Success : osmanerken
# Success : fatmaaladag
# Success : sehir_iletisim
# Success : eozkan13
# Success : vahap_coskun
# Success : ehibba
# Success : yusuf_akbal
# Error : File b'data/clean/kubraabasturk_cleaned.csv' does not exist for kubraabasturk
# Success : esmemis
# Success : S_Begenjov
# Success : betulkocalii
# Error : File b'data/clean/bugraerarslan_cleaned.csv' does not exist for bugraerarslan
# Success : gokhanak_ak
# Success : Balciceki
# Success : hamakirsali
# Error : File b'data/clean/GokhanBacik_cleaned.csv' does not exist for GokhanBacik
# Success : pbayrak11
# Success : h_suheyl
# Success : canacun
# Success : sehiryesilay
# Success : mhkrgz
# Success : wendtist
# Success : cengizsunar
# Success : ahmdbll
# Success : mahmutsami12
# Success : Seyyarmasalci
# Success : serapsaracli
# Success : IDatSEHIR
# Success : abdullahbahci1
# Success : kureyayinlari
# Success : aczvefakr
# Success : sulerumeysae
# Success : Sinemmpala
# Success : Mertmengu
# Success : Jaharrad
# Success : nedtahir
# Success : Academia_ISU
# Error : File b'data/clean/osmnbyrk_cleaned.csv' does not exist for osmnbyrk
# Error : File b'data/clean/eucak_cleaned.csv' does not exist for eucak
# Success : arsub_b
# Success : MiranCetiner
# Error : File b'data/clean/nihansusinmez_cleaned.csv' does not exist for nihansusinmez
# Error : File b'data/clean/esrapulcu_cleaned.csv' does not exist for esrapulcu
# Success : mucahitbilici
# Success : goygoyhukuk
# Success : AytekinBusra
# Error : File b'data/clean/olpmox_cleaned.csv' does not exist for olpmox
# Error : File b'data/clean/Ordinaryus1907_cleaned.csv' does not exist for Ordinaryus1907
# Success : sehiricebreaker
# Success : sehirtto
# Success : nihanyapar
# Success : klmynr
# Success : ebu_sehr
# Success : ogfurkan
# Success : terraincognitae
# Success : hatemete
# Error : Cannot feed value of shape (0,) for Tensor 'Placeholder:0', which has shape '(?, 300)' for ethemkarademir
# Success : busrasafak
# Success : aysegulyesiil
# Success : lokmanokten
# Success : mutehayyel
# Success : denizerbedir
# Success : SehirSBE
# Success : vesayrevesaire
# Success : byazmaci
# Success : sehiriletisim
# Success : hazarekecik
# Success : Lazzyto
# Success : aysenurkoc5
# Success : zelaldirekcii
# Error : File b'data/clean/ilovecihangir_cleaned.csv' does not exist for ilovecihangir
# Success : bejanmatur
# Success : reyyanaynur
# Success : welfaredist
# Success : KyoPino
# Error : File b'data/clean/_mutekellim__cleaned.csv' does not exist for _mutekellim_
# Success : Bornimagoo
# Success : incinbaa
# Success : Yabkanes
# Success : Sevdes
# Success : yavuzgozeller
# Success : eyisen
# Success : sehirhaber
# Success : cinarkerem
# Error : File b'data/clean/SumeyyeII_cleaned.csv' does not exist for SumeyyeII
# Success : tahaun
# Success : seyma353
# Success : harun5334
# Success : Aysegulmek
# Success : burcinbakrci
# Error : File b'data/clean/elifnurkayalar_cleaned.csv' does not exist for elifnurkayalar
# Success : OsamaSeyam92
# Error : File b'data/clean/unveresra_cleaned.csv' does not exist for unveresra
# Success : zulalucisik
# Success : ersinoe
# Success : msamilonder
# Success : sofistiiike
# Error : File b'data/clean/sseyma_z_cleaned.csv' does not exist for sseyma_z
# Error : Cannot feed value of shape (0,) for Tensor 'Placeholder:0', which has shape '(?, 300)' for istnbulsehrunii
# Error : Cannot feed value of shape (0,) for Tensor 'Placeholder:0', which has shape '(?, 300)' for YazanAlterkawi
# Success : enesaltunbas
# Error : File b'data/clean/gaziigiray_cleaned.csv' does not exist for gaziigiray
# Error : File b'data/clean/zeynebtuf__cleaned.csv' does not exist for zeynebtuf_
# Error : Cannot feed value of shape (0,) for Tensor 'Placeholder:0', which has shape '(?, 300)' for RatebAltal
# Success : zottorihanzo
# Error : File b'data/clean/RbCeylan_cleaned.csv' does not exist for RbCeylan
# Success : MaadSharaf
# Success : MehmetBurakDikm
# Error : File b'data/clean/beytullahemrah_cleaned.csv' does not exist for beytullahemrah
# Success : nsenaa
# Success : otdergi
# Error : File b'data/clean/alihankoca_cleaned.csv' does not exist for alihankoca
# Success : Selmankurtulmus
# Success : cay_hane
# Success : dihizlan
# Error : File b'data/clean/YusufSuphiTemel_cleaned.csv' does not exist for YusufSuphiTemel
# Success : RtSehir
# Success : y_eacar
# Success : hatice_sari
# Success : agcatamer
# Success : aysepk
# Success : ayselivermore
# Success : SehirKonsey
# Success : orhanguler1
# Success : mervdgny
# Error : File b'data/clean/OolcanPnr_cleaned.csv' does not exist for OolcanPnr
# Success : TahaColakoglu
# Success : senefii
# Success : ragipsoylu
# Success : FUATUGUR
# Success : yigit_bozkurt
# Error : File b'data/clean/Sevinnabi_cleaned.csv' does not exist for Sevinnabi
# Success : asimoncel
# Success : cagrikosak
# Error : File b'data/clean/karataslymn_cleaned.csv' does not exist for karataslymn
# Success : ahysnn
# Success : nzheozyzicioglu
# Success : SehirTarih
# Success : sevdersoyy
# Error : File b'data/clean/meryemyetkin_cleaned.csv' does not exist for meryemyetkin
# Success : mahmutpancar
# Success : erennhavlucu
# Error : File b'data/clean/hilalerturk_cleaned.csv' does not exist for hilalerturk
# Error : File b'data/clean/EsraUslupat_cleaned.csv' does not exist for EsraUslupat
# Success : mbuyukmatur
# Success : bfdellaloglu
# Success : RealFirdaous
# Error : File b'data/clean/zebiun_cleaned.csv' does not exist for zebiun
# Success : SehirMuhKulubu
# Error : File b'data/clean/Kajubey_cleaned.csv' does not exist for Kajubey
# Error : File b'data/clean/theareveur_cleaned.csv' does not exist for theareveur
# Success : malibuyukkara
# Success : khumeira
# Success : direkciseyma
# Success : HuseyinYayman
# Success : sadadergisi
# Error : File b'data/clean/_samiyigit_cleaned.csv' does not exist for _samiyigit
# Success : furkankinik
# Success : nurundamla
# Error : File b'data/clean/muhtaryasir_cleaned.csv' does not exist for muhtaryasir
# Error : File b'data/clean/aferimcokguzel_cleaned.csv' does not exist for aferimcokguzel
# Success : egurgoze
# Success : tekhareketi
# Error : File b'data/clean/essrup_cleaned.csv' does not exist for essrup
# Error : File b'data/clean/yusufcos_cleaned.csv' does not exist for yusufcos
# Error : File b'data/clean/dogukankotan_cleaned.csv' does not exist for dogukankotan
# Success : zahitatcil
# Success : cemilyavuzing
# Success : surdangecti
# Success : Politolog00
# Success : emrahkayad
# Success : manilkoc
# Error : File b'data/clean/ozdemirrbusra_cleaned.csv' does not exist for ozdemirrbusra
# Success : sivilses
# Success : rukiaydin
# Success : KabarBey_
# Success : sehrinnotcusu
# Success : yalcinari
# Success : fatialtug
# Success : sehirunigezi
# Error : File b'data/clean/eliffuzell_cleaned.csv' does not exist for eliffuzell
# Success : EdaKplan
# Success : hilal_kaplan
# Success : aatcil
# Success : argosehir
# Success : be__ce
# Success : ibrahimutlu38
# Success : ahdamar
# Success : ErkamKARAKAYA
# Success : alirizabsr
# Success : sehomanya
# Success : rumhfzoglu
# Success : aysenurertem_
# Success : melikdaye
# Error : File b'data/clean/Sh4dett_cleaned.csv' does not exist for Sh4dett
# Success : ahmetyesiltepe
# Success : huzasim
# Success : travissbickle
# Success : eyado7
# Success : alicnclk
# Success : GulsahMrt
# Success : furkntasar
# Success : sehiruniv
# Success : betulengin
# Success : ayenor
# Error : Cannot feed value of shape (0,) for Tensor 'Placeholder:0', which has shape '(?, 300)' for AlajdinR
# Success : yusufbayazit
# Success : AbdullahTerzi_
# Success : seydanlioglu
# Error : File b'data/clean/Acaristaan_cleaned.csv' does not exist for Acaristaan
# Success : inanamiyorumki
# Error : File b'data/clean/MustafaUgurlu_cleaned.csv' does not exist for MustafaUgurlu
# Success : satuskicha
# Success : sehiruni118
# Success : RobertDurst_
# Success : sehirsanat
# Success : kokonadespina
# Success : elvina_gulverdi
# Success : _rumeysaozturk
# Success : mrtgokdemir
# Error : File b'data/clean/ceydatatari_cleaned.csv' does not exist for ceydatatari
# Error : File b'data/clean/mmalikinci_cleaned.csv' does not exist for mmalikinci
# Success : adliforum
# Success : bhicretyavuz
# Success : fragileworldamn
# Error : File b'data/clean/uzunyaylaagasi_cleaned.csv' does not exist for uzunyaylaagasi
# Error : File b'data/clean/SNurSeker_cleaned.csv' does not exist for SNurSeker
# Error : File b'data/clean/avci_feyza_cleaned.csv' does not exist for avci_feyza
# Success : rumeysasenglu
# Success : TUZBEDIRHAN
# Success : ifurkantr
# Success : meneserkan
# Success : BEYTYZC
# Error : File b'data/clean/mlsmelis96_cleaned.csv' does not exist for mlsmelis96
# Success : osmoticpheno
# Success : ALIATIFBIR
# Success : mikrofonisehir
# Error : File b'data/clean/AfA_1905_cleaned.csv' does not exist for AfA_1905
# Success : ahmtbrkl
# Success : busrasargin53
# Error : File b'data/clean/zahsenk_cleaned.csv' does not exist for zahsenk
# Error : File b'data/clean/seymaasahinn_cleaned.csv' does not exist for seymaasahinn
# Error : File b'data/clean/tugbagayretli_cleaned.csv' does not exist for tugbagayretli
# Success : sehirmusicclub
# Success : Aliskaya
# Success : 2el1firca
# Error : File b'data/clean/humeyraseles_cleaned.csv' does not exist for humeyraseles
# Success : mehmetmertkesti
# Success : SehirGonullusu
# Success : AyseSenaOkuyan
# Success : harbisinema
# Error : File b'data/clean/SCansuYaman_cleaned.csv' does not exist for SCansuYaman
# Success : Birkantekin
# Success : YavuzYigit
# Success : SaitMahmut
# Success : matmazeldedigin
# Success : M_Ali_Caliskan
# Success : cikorita_
# Success : aaltundal7
# Error : File b'data/clean/busraholmes_cleaned.csv' does not exist for busraholmes
# Success : CetinkayaEgemen
# Error : File b'data/clean/ZeynepSaracbasi_cleaned.csv' does not exist for ZeynepSaracbasi
# Success : mkarabasoglu
# Error : File b'data/clean/gulnihalli_cleaned.csv' does not exist for gulnihalli
# Success : Seri_Reis
# Success : Halimalbakkor
# Success : muhendisimtirak
# Success : karakaya_behlul
# Success : muratyesiltas
# Success : omerkacmen
# Error : File b'data/clean/ebubekiryldzts_cleaned.csv' does not exist for ebubekiryldzts
# Success : ilhantunahanbas
# Success : DagtekinBilal
# Success : elifdonmez
# Error : File b'data/clean/ismailhakkihira_cleaned.csv' does not exist for ismailhakkihira
# Success : ssibgatullahh
# Success : tycitil
# Success : detroitlikizil
# Success : demiraysaliha
# Success : sehirfest
# Success : tunahanelmass
# Success : daim_munzevii
# Success : Abdul_shibli
# Success : kelyazar
# Success : busracicen
# Success : JumailiAhmed
# Error : File b'data/clean/Muleyke_B_cleaned.csv' does not exist for Muleyke_B
# Error : File b'data/clean/orhansalihd_cleaned.csv' does not exist for orhansalihd
# Success : mtozresch
# Success : CHB_Avsadi
# Success : klasikyayinlari
# Error : File b'data/clean/byzkarahan_cleaned.csv' does not exist for byzkarahan
# Success : ahmettarikeren
# Success : ofarukcaliskan
# Success : ozgulgeles
# Success : jaefercan
# Error : Cannot feed value of shape (0,) for Tensor 'Placeholder:0', which has shape '(?, 300)' for JamalSomaya
# Success : ahmetcklc
# Success : istdusevi
# Success : azadesel
# Error : File b'data/clean/kmlmstf25_cleaned.csv' does not exist for kmlmstf25
# Success : ugrmtc
# Success : lutfiyesevde
# Success : msercanercan
# Success : ysfsahan
# Success : yiitche
# Success : alperrrrrrrrr
# Success : babelfishly
# Success : hacertilbec
# Success : busra_bulut
# Error : File b'data/clean/McLolty_cleaned.csv' does not exist for McLolty
# Success : teceeralp
# Success : alpionel
# Success : erkanshen
# Error : File b'data/clean/egkceaksoy_cleaned.csv' does not exist for egkceaksoy
# Success : eminilbeyli
# Success : mazharbagli
# Success : h_mustafaozel
# Success : iamemrekaraman
# Success : fnzehra
# Success : sevdealtunn
# Success : halitbekiroglu
# Success : havvasula
# Success : elifesrayvz
# Success : isifsehir
# Success : arslantaszeynep
# Success : kkopuz
# Error : File b'data/clean/nurpuytu_cleaned.csv' does not exist for nurpuytu
# Success : kelemetcigdem
# Success : muhammedalisit
# Success : jenarcik
# Success : nebimis
# Success : taliasibai
# Success : ferhatkentel
# Success : yavuzluselim
# Success : ErdemOkurFans
# Error : Cannot feed value of shape (0,) for Tensor 'Placeholder:0', which has shape '(?, 300)' for FdnAli
# Success : MalikShabanov
# Success : hbaranf
# Error : File b'data/clean/besterarslan_cleaned.csv' does not exist for besterarslan
# Success : HEKVA_
# Success : ssysfakb
# Error : Cannot feed value of shape (0,) for Tensor 'Placeholder:0', which has shape '(?, 300)' for Allhass95
# Success : sifanurhacer
# Success : AliEminKrgz
# Success : EbrarAydn5
# Error : File b'data/clean/baskasi_cleaned.csv' does not exist for baskasi
# Success : ISIKERFiliz
# Success : burak_altun_
# Error : File b'data/clean/tonoglumustafa_cleaned.csv' does not exist for tonoglumustafa
# Success : hasipayanoglu
# Success : omerfarukunver
# Success : nesosyologu
# Success : UsamErdogan
# Success : efmertesacker
# Success : sehirgezikulubu
# Success : ofmoriste
# Success : HalukDortluoglu
# Error : File b'data/clean/AladagSaid_cleaned.csv' does not exist for AladagSaid
# Success : ozerenbeyza
# Success : eliffbanu
# Success : Vaporjulep
# Success : psikolojiktir
# Success : maliustun
# Success : zehratula
# Success : hulyakdz
# Success : EfekanBenlier
# Success : moikinda
# Success : gulsahmican
# Error : File b'data/clean/behramkoca_cleaned.csv' does not exist for behramkoca
# Success : mfurkanyavuz
# Success : beyinsiz_adam
# Success : abdkaraarslan
# Success : makbuladimlar
# Success : Candan_Dost
# Success : _Biladerler
# Success : msgonullu
# Success : nottafound
# Error : File b'data/clean/Falsemansfalse_cleaned.csv' does not exist for Falsemansfalse
# Success : semssami
# Success : orjinalinsan_
# Success : hidirgevis
# Success : husalptekin
# Success : withheld_accnt
# Success : istmcc
# Success : EyupGokcee
# Success : fdindarol
# Success : isshhak
# Success : tunakocaman
# Success : ramazanodunccu
# Error : File b'data/clean/KokchaZ_cleaned.csv' does not exist for KokchaZ
# Error : File b'data/clean/baharalb_cleaned.csv' does not exist for baharalb
# Success : ahsensurucu
# Success : ibrahimizgi
# Error : File b'data/clean/AAkkoyunn_cleaned.csv' does not exist for AAkkoyunn
# Success : serraaltay
# Success : sehirsosyal
# Success : AhmetOztemz
# Success : bsvmam
# Success : YldzRamazanolu
# Success : salihadiyaman
# Success : islamsozler
# Success : _____l_l_____
# Error : File b'data/clean/MerdiQerechi_cleaned.csv' does not exist for MerdiQerechi
# Success : Cihadinan
# Success : lazamani
# Success : kutluerilhan
# Success : belizeee
# Success : GokhanBicici
# Success : HulkinAdami
# Success : dikkenar
# Success : Aysegulpayci
# Success : _oteki_
# Success : Korkut__Fatih
# Error : File b'data/clean/umrangulbin_cleaned.csv' does not exist for umrangulbin
# Error : File b'data/clean/matricariamilla_cleaned.csv' does not exist for matricariamilla
# Success : mim_mfd
# Success : sedatkucukbay
# Success : sadecefm
# Success : MeryemSuliman
# Error : File b'data/clean/alperilealper_cleaned.csv' does not exist for alperilealper
# Success : umit_aksoy
# Success : birgariparaf
# Success : odmanasli
# Success : salimyavuz
# Success : yunuzo
# Success : SehirKariyer
# Success : zemeuu
# Success : eneskandur1
# Success : bananbnbn
# Success : safsatta
# Success : TheAfrasiyab
# Success : gnageeb
# Success : avcioral
# Success : selimliyavuz
# Success : IHalilUcer
# Error : File b'data/clean/akfyksl_cleaned.csv' does not exist for akfyksl
# Success : Cengizbeyza
# Error : File b'data/clean/melis_hafez_cleaned.csv' does not exist for melis_hafez
# Success : anbyildirim
# Error : File b'data/clean/KlcDlara_cleaned.csv' does not exist for KlcDlara
# Success : davettoplulugu
# Success : FigenIlke
# Success : safkanafkan
# Error : File b'data/clean/SelimDemirkynk_cleaned.csv' does not exist for SelimDemirkynk
# Error : File b'data/clean/senaadonmezz_cleaned.csv' does not exist for senaadonmezz
# Success : goksukeserbi
# Success : ZaferQassami
# Success : arkakapak
# Success : urbanhobbit
# Success : balikgoz
# Success : yasinTii
# Error : File b'data/clean/ezraozsoy_cleaned.csv' does not exist for ezraozsoy
# Success : ramazancadiri
# Error : File b'data/clean/hanifecatan_cleaned.csv' does not exist for hanifecatan
# Success : _sedatulusoy
# Success : mr_kaks1
# Success : ofabiof
# Error : File b'data/clean/ibrahmcikrikci_cleaned.csv' does not exist for ibrahmcikrikci
# Success : Mazlumder_World
# Success : aysenuryahsi
# Success : salihecevit
# Success : socsehir
# Error : File b'data/clean/hakanbayrakk_cleaned.csv' does not exist for hakanbayrakk
# Error : File b'data/clean/rektoratif_cleaned.csv' does not exist for rektoratif
# Success : hramiustun
# Error : File b'data/clean/snnogluberra_cleaned.csv' does not exist for snnogluberra
# Success : ahmetkahveciler
# Success : s_simityan
# Success : erdemytt
# Success : wafflecim
# Success : hoposinanay
# Error : File b'data/clean/carslan61_cleaned.csv' does not exist for carslan61
# Success : asamiozen
# Success : afsolmaz
# Success : ayergisen
# Success : fzcerci
# Success : muakkib
# Success : ohannes_klcdg
# Error : File b'data/clean/suhedaduzcan_cleaned.csv' does not exist for suhedaduzcan
# Success : okanncakarr1
# Success : huseyingurbanov
# Success : mufidyuksel
# Success : sinanbolukoglu
# Success : sehirdegisim
# Success : ergulmhuseyin
# Success : okurerdem
# Success : yasemincakirer
# Error : File b'data/clean/mzbalkas_cleaned.csv' does not exist for mzbalkas
# Success : Zeina172
# Success : aksubora
# Success : KerimOZAL
# Success : rumeysagecer
# Success : GulnihalAydinli
# Error : Cannot feed value of shape (0,) for Tensor 'Placeholder:0', which has shape '(?, 300)' for worldbulletin
# Success : risusku
# Success : sgrbll
# Success : JournalSehir
# Success : SehirCHES
# Success : hiyenigun
# Success : esrefisark
# Success : nihaterdogmus
# Success : hediyetullah_
# Success : mhmtaytkn
# Error : File b'data/clean/nurulu__cleaned.csv' does not exist for nurulu_
# Success : bilalrdv
# Success : haticeaynurr
# Success : SafiyeSideli
# Success : TemimHocaoglu
# Error : File b'data/clean/sen_a_nur_cleaned.csv' does not exist for sen_a_nur
# Success : ruhavi
# Success : aakkgul
# Success : usamevahap
# Success : miailayda
# Error : File b'data/clean/Bsrayrkcglu_cleaned.csv' does not exist for Bsrayrkcglu
# Error : File b'data/clean/maligultekinn_cleaned.csv' does not exist for maligultekinn
# Success : sukrukibar
# Success : semanurkonuk_
# Error : File b'data/clean/carullah_rumi_cleaned.csv' does not exist for carullah_rumi
# Success : BekirZahid
# Error : File b'data/clean/mertsaydogan_cleaned.csv' does not exist for mertsaydogan
# Error : File b'data/clean/nbyerli_cleaned.csv' does not exist for nbyerli
# Success : iReMCaNaNN
# Error : File b'data/clean/reshadetimanov_cleaned.csv' does not exist for reshadetimanov
# Success : seyharsanoy
# Success : cakir_rusen
# Error : File b'data/clean/esbeyazz_cleaned.csv' does not exist for esbeyazz
# Success : senaadibeke
# Success : zbakyildiz
# Success : huzeyfeakkoyun
# Error : File b'data/clean/YasinSaglam7_cleaned.csv' does not exist for YasinSaglam7
# Success : ahofu
# Error : File b'data/clean/talhaasil_cleaned.csv' does not exist for talhaasil
# Success : esihatun
# Success : nsugur
# Success : mtalhakaan
# Success : senerboztas
# Success : sismanadam
# Success : _elifcelebi
# Success : Freuudd
# Success : hakirim
# Success : Mtn1907Snmz
# Success : ayasinoncu
# Success : Talha_Kose1
# Success : abadeeel
# Success : SehirDance
# Success : AliTahaYilki
# Success : hilsehir
# Success : zzahidec
# Success : cerenkenar
# Success : saidercan
# Success : Mstfozl
# Success : isamerIU
# Success : sibeleraslan
# Error : File b'data/clean/aylavkis_cleaned.csv' does not exist for aylavkis
# Success : yzciyusuf
# Success : MA_Sevinc
# Success : tumsuz
# Success : sehirliolmak
# Error : File b'data/clean/konevim_cleaned.csv' does not exist for konevim
# Error : File b'data/clean/_apoikia_cleaned.csv' does not exist for _apoikia
# Error : File b'data/clean/sinoypexas_cleaned.csv' does not exist for sinoypexas
# Error : File b'data/clean/azenginn_cleaned.csv' does not exist for azenginn
# Success : ebuzercaliskan
# Error : File b'data/clean/huseyintarik_cleaned.csv' does not exist for huseyintarik
# Success : zeynebbus
# Error : File b'data/clean/ZuhalCevahir_cleaned.csv' does not exist for ZuhalCevahir
# Error : File b'data/clean/mnsaylik_cleaned.csv' does not exist for mnsaylik
# Success : sehirkedileri
# Error : File b'data/clean/yesimksknn_cleaned.csv' does not exist for yesimksknn
# Success : yalcinn16
# Success : feyzanr_tastkne
# Success : abbassem
# Success : berendaz
# Error : File b'data/clean/tklhc_cleaned.csv' does not exist for tklhc
# Success : sehirlibrary
# Success : SGormezdengelme
# Success : edanurbeyoglu
# Success : nurbikhasta
# Success : aytenkoldemir
# Success : irosehir
# Success : dino_baggiooo
# Success : suigenerisloris
# Success : bilen_hacer
# Success : FurkanAkbal
# Success : nibenka
# Success : amerikabulteni
# Error : File b'data/clean/besincimevsim_cleaned.csv' does not exist for besincimevsim
# Error : File b'data/clean/Yahyayacoob_cleaned.csv' does not exist for Yahyayacoob
# Error : File b'data/clean/uludagTayyip_cleaned.csv' does not exist for uludagTayyip
# Error : File b'data/clean/N_Rsena_cleaned.csv' does not exist for N_Rsena
# Error : File b'data/clean/NurullahArdic_cleaned.csv' does not exist for NurullahArdic
# Success : cokmukomiksert
# Success : cemalgunaydn
# Success : emre_keskus
# Success : zeynebsultan
# Success : yusufelbasi
# Success : suleyld
# Success : Fikrsiz
# Success : bsrdgc1
# Error : File b'data/clean/tesnimozdinc_cleaned.csv' does not exist for tesnimozdinc
# Error : File b'data/clean/banaelifde_cleaned.csv' does not exist for banaelifde
# Error : File b'data/clean/lltoprak_cleaned.csv' does not exist for lltoprak
# Error : File b'data/clean/beyjey_cleaned.csv' does not exist for beyjey
# Success : surhewz
# Success : ssewecen
# Success : ozguralik
# Success : BirKizBirOglan
# Success : esoruc
# Success : hamza_sis
# Success : reyyanmunire
# Success : huseyinikizoglu
# Success : Sumeyra_Ozturk_
# Success : ZenginGurkan
# Error : File b'data/clean/mervesenel__cleaned.csv' does not exist for mervesenel_
# Error : File b'data/clean/ibrahimcansu__cleaned.csv' does not exist for ibrahimcansu_
# Error : File b'data/clean/bernottit_cleaned.csv' does not exist for bernottit
# Success : kral
# Error : Cannot feed value of shape (0,) for Tensor 'Placeholder:0', which has shape '(?, 300)' for RamadanTent
# Success : ZeynepIlkkursun
# Success : SehirHUKUK
# Success : y_sarfati
# Error : File b'data/clean/mrvaldg_cleaned.csv' does not exist for mrvaldg
# Error : File b'data/clean/AlperenDuymus_cleaned.csv' does not exist for AlperenDuymus
# Success : Aljalmoud
# Success : mhmmdklss
# Success : AliPulcu
# Success : alihaliduslu
# Success : sehircareerfest
# Success : mustafazengins
# Success : Kan3anio
# Success : FZehraErcan
# Success : makifmemmi
# Error : File b'data/clean/gulucukgulucuk_cleaned.csv' does not exist for gulucukgulucuk
# Success : akbaskevserr
# Error : File b'data/clean/emervetekdemir_cleaned.csv' does not exist for emervetekdemir
# Success : ayseguveli
# Success : Sehir_Lab
# Success : ebruaraci
# Error : File b'data/clean/RbtKlk_cleaned.csv' does not exist for RbtKlk
# Error : File b'data/clean/mrbozz_cleaned.csv' does not exist for mrbozz
# Error : File b'data/clean/ezgcnbz_cleaned.csv' does not exist for ezgcnbz
# Success : tufeyli_
# Success : OGUZISMAILOGLU
# Success : msmorkan
# Success : msenel
# Success : DivanDergisi
# Success : simorgilas
# Success : menescio647
# Error : File b'data/clean/mrvoztrka_cleaned.csv' does not exist for mrvoztrka
# Error : File b'data/clean/bbrkci__cleaned.csv' does not exist for bbrkci_
# Success : Smeyyetemell
# Success : betultastan
# Success : ikbalarmagan
# Success : sedadi
# Success : mtahasamasti
# Error : File b'data/clean/svmkirac_cleaned.csv' does not exist for svmkirac
# Success : minval_
# Error : File b'data/clean/ezgimermer_cleaned.csv' does not exist for ezgimermer
# Error : File b'data/clean/andacmusa_cleaned.csv' does not exist for andacmusa
# Success : melmetintas
# Success : incubacity
# Success : sehirliderlik
# Error : File b'data/clean/hkosebalaban1_cleaned.csv' does not exist for hkosebalaban1
# Success : AKSehirUni
# Error : File b'data/clean/wwevergreen_cleaned.csv' does not exist for wwevergreen
# Success : esranurkose
# Success : alibazfatih
# Error : File b'data/clean/TuncayHasibe_cleaned.csv' does not exist for TuncayHasibe
# Success : idrissahinturk
# Success : MhmtSlmz
# Error : File b'data/clean/yamoonz_cleaned.csv' does not exist for yamoonz
# Success : selimyaman_
# Error : Cannot feed value of shape (0,) for Tensor 'Placeholder:0', which has shape '(?, 300)' for label
# Error : File b'data/clean/turhanays_cleaned.csv' does not exist for turhanays
# Success : ramazanaras
# Success : muratkucukvar
# Success : enes_avar
# Error : File b'data/clean/NeslihanTezcn_cleaned.csv' does not exist for NeslihanTezcn
# Success : cavusunhace
# Error : File b'data/clean/alpersoyupak_cleaned.csv' does not exist for alpersoyupak
# Error : File b'data/clean/aysnresr_cleaned.csv' does not exist for aysnresr
# Success : DKose__
# Success : nessyys
# Success : darisaadetsehir
# Success : zddemir_
# Success : avmbalci
# Success : msapaydin
# Error : File b'data/clean/ZeyneepSinan_cleaned.csv' does not exist for ZeyneepSinan
# Error : Cannot feed value of shape (0,) for Tensor 'Placeholder:0', which has shape '(?, 300)' for DablanMayasa
# Error : File b'data/clean/zfeyza_cleaned.csv' does not exist for zfeyza
# Error : File b'data/clean/soceylul_cleaned.csv' does not exist for soceylul
# Error : Cannot feed value of shape (0,) for Tensor 'Placeholder:0', which has shape '(?, 300)' for reyta_akdeniz
# Success : mudahilpachi
# Success : latffest
# Success : mustafasenbd
# Success : sedatlaciner
# Error : File b'data/clean/yurtalan92_cleaned.csv' does not exist for yurtalan92
# Success : mihmandarbyztpz
# Success : BelksKlkaya
# Error : File b'data/clean/zynpaslihn_cleaned.csv' does not exist for zynpaslihn
# Error : File b'data/clean/unfabulousdt__cleaned.csv' does not exist for unfabulousdt_
# Error : File b'data/clean/aozturk1_cleaned.csv' does not exist for aozturk1
# Success : tugtagelif
# Success : m_colak_
# Success : sehirkadem
# Success : betullcolak
# Success : isifkulubu
# Success : EsadGokdemir
# Success : filizkayann
# Success : Sam_Al_Ghammari
# Success : kuche_rindan
# Success : profdralikose
# Success : fzfz53
# Success : sehir14
# Error : File b'data/clean/mrvebayram_cleaned.csv' does not exist for mrvebayram
# Success : malcolmiye
# Success : uguryunus
# Success : ibrahimusaonder
# Success : mskdmrbsr
# Error : File b'data/clean/mdaliaydin_cleaned.csv' does not exist for mdaliaydin
# Success : OmerFatsa
# Error : File b'data/clean/NilsuKYN_cleaned.csv' does not exist for NilsuKYN
# Error : File b'data/clean/eylulco_cleaned.csv' does not exist for eylulco
# Success : azrafsin
# Success : emrahakbas
# Success : suhedaaricii
# Success : salihdogan_
# Error : File b'data/clean/Zarella92_cleaned.csv' does not exist for Zarella92
# Success : SevdeKurt
# Success : 34DRU94
# Success : aybukeyazici
# Error : File b'data/clean/BetulAkova_cleaned.csv' does not exist for BetulAkova
# Success : elifdolapcioglu
# Success : 2kita1mutluluk
# Success : sehirunisikayet
# Success : farukozcetin
# Success : sehirpolitika
# Success : serdarbs
# Success : kirkolesi
# Success : shybrdmci
# Success : alev_erkilet
# Error : File b'data/clean/mselimkarsli_cleaned.csv' does not exist for mselimkarsli
# Error : File b'data/clean/ebrausta_cleaned.csv' does not exist for ebrausta
# Success : maydemir1001
# Success : fdemirci
# Success : drkerem
# Error : File b'data/clean/Melodia_B_cleaned.csv' does not exist for Melodia_B
# Success : Alwaysprep
# Success : anatolianirfan
# Success : zeynpylmaz
# Success : _yakebikec
# Success : yinemizeze
# Success : sehirmgtclub
# Success : bilalhorasan
# Error : File b'data/clean/HusniyeKoc_cleaned.csv' does not exist for HusniyeKoc
# Success : kdrtemiz
# Success : YavuzSelimKol
# Success : SehirDragos
# Success : Firattalha
# Success : ofkocum
# Success : ozgurcelaleddin
# Error : File b'data/clean/Bahaksit_cleaned.csv' does not exist for Bahaksit
# Success : cizikplak
# Success : DilaraDemir3
# Success : SehirGirisim
# Success : HazalTurhan
# Success : MYasirOkumus
# Success : qbitclub
# Success : MerveMuzmul
# Success : abalci
# Success : enisberkc
# Error : File b'data/clean/VildanKadioglu_cleaned.csv' does not exist for VildanKadioglu
# Error : File b'data/clean/furkancakmak_cleaned.csv' does not exist for furkancakmak
# Success : eeslems
# Success : korfoula_
# Success : RanaGulnihal
# Success : sehrifotograf
# Success : Simurger
# Success : Afurkanakbulut
# Success : furkanysr
# Success : olafaybk
# Error : File b'data/clean/Seyyidesifa__cleaned.csv' does not exist for Seyyidesifa_
# Success : hortumcuzk
# Success : itaatsiz
# Success : sehirmed
# Error : File b'data/clean/esadunal_cleaned.csv' does not exist for esadunal
# Success : RanaKurt
# Error : File b'data/clean/aysenuryurttas_cleaned.csv' does not exist for aysenuryurttas
# Success : gkhngol
# Error : File b'data/clean/ergul_aysenur_cleaned.csv' does not exist for ergul_aysenur
# Success : kamilardaelif
# Error : File b'data/clean/_hepyek_cleaned.csv' does not exist for _hepyek
# Success : sehiratolye
# Success : abdulaziztalha
# Error : Cannot feed value of shape (0,) for Tensor 'Placeholder:0', which has shape '(?, 300)' for muhammed_hasan
# Success : hayallervarya
# Success : ErturkMahmud
# Success : yunusdemir1453
# Success : onurguzey
# Success : SernurY
# Error : File b'data/clean/EleyanMe_cleaned.csv' does not exist for EleyanMe
# Success : dilsizdilci
# Success : ahmetabdallah
# Success : seyma_topcu
# Success : hby34
# Success : tugrulbakir
# Success : gencmots
# Error : File b'data/clean/vlldn_cleaned.csv' does not exist for vlldn
# Success : kinlikleri
# Success : guruntu
# Success : ahmetfarukeker
# Success : bnoktadino
# Success : ozdagsemihaa
# Success : kamilturan_
# Success : parmakuclari
# Error : File b'data/clean/fatma_denizz_cleaned.csv' does not exist for fatma_denizz
# Success : meliketuloglu
# Success : arasbulent
# Success : myasiny13
# Success : zubyde_melek
# Success : tarcinlielmali
# Success : Seda_Ozen
# Success : AybikeUluc
# Success : MustafaOzelden
# Success : MCanErim
# Success : myilmaz_67
# Success : Quce_gezen
# Success : karamzalininki
# Success : osmansrt
# Success : bahadirbektas61
# Success : a_enesozel
# Success : esraakbulak____
# Success : BehlulOzkan
# Error : File b'data/clean/smlerkam_cleaned.csv' does not exist for smlerkam
# Success : muhammedtoprak
# Success : DelikayaSinan
# Success : sadecekisi
# Error : File b'data/clean/NursenaOzcan_cleaned.csv' does not exist for NursenaOzcan
# Success : cengizkallek
# Error : File b'data/clean/tuncaykardas_cleaned.csv' does not exist for tuncaykardas
# Success : Beyza_nuur
# Error : File b'data/clean/negahkon_cleaned.csv' does not exist for negahkon
# Success : senerakturk
# Error : File b'data/clean/sevgiblgc_cleaned.csv' does not exist for sevgiblgc
# Success : harabatkahve
# Success : STkariyer
# Success : celileco
# Error : File b'data/clean/atsekc_cleaned.csv' does not exist for atsekc
# Success : granieve
# Success : ZubeyirNisanci
# Error : File b'data/clean/gamdefterdari_cleaned.csv' does not exist for gamdefterdari
# Success : entelmilitan
# Success : seymaberberoglu
# Error : File b'data/clean/aybein_cleaned.csv' does not exist for aybein
# Success : AlaaAlChalabi
# Success : YzeydanK
# Error : File b'data/clean/abdussamedtkdmr_cleaned.csv' does not exist for abdussamedtkdmr
# Success : rnur_
# Error : File b'data/clean/zry_kr_cleaned.csv' does not exist for zry_kr
# Error : File b'data/clean/mazrub_cleaned.csv' does not exist for mazrub
# Error : File b'data/clean/Zaaaino_cleaned.csv' does not exist for Zaaaino
# Error : File b'data/clean/MelihTalu_cleaned.csv' does not exist for MelihTalu
# Error : Cannot feed value of shape (0,) for Tensor 'Placeholder:0', which has shape '(?, 300)' for MamdoohDayem
# Success : EDmlpnr
# Success : AEskilerr
# Success : sehirdiplomasi
# Success : Ycaliska10
# Error : File b'data/clean/iremtatlidedee_cleaned.csv' does not exist for iremtatlidedee
# Error : File b'data/clean/mmeryemcee_cleaned.csv' does not exist for mmeryemcee
# Success : ergun_hanife
# Error : File b'data/clean/ozlem_albayrak_cleaned.csv' does not exist for ozlem_albayrak
# Error : File b'data/clean/msumeyyekaraca_cleaned.csv' does not exist for msumeyyekaraca
# Success : yekarahan
# Success : mucahitkyilmaz
# Success : hacerkor
# Success : cetinsayag
# Success : fatimatubapetek
# Success : sadikunay
# Error : File b'data/clean/bugrahantanir_cleaned.csv' does not exist for bugrahantanir
# Error : File b'data/clean/tzachint_cleaned.csv' does not exist for tzachint
# Error : Cannot feed value of shape (0,) for Tensor 'Placeholder:0', which has shape '(?, 300)' for maddy_sb94
# Success : fusariyasar
# Error : File b'data/clean/serhatacikel_cleaned.csv' does not exist for serhatacikel
# Success : burcu_saglam
# Error : File b'data/clean/algahafy_cleaned.csv' does not exist for algahafy
# Success : kayyum1905
# Success : rabiaozkn06
# Success : FerdanErgut
# Success : KayaOzlemm
# Success : BisavTAM
# Error : File b'data/clean/YildirimEbr_cleaned.csv' does not exist for YildirimEbr
# Success : Aliyasar93
# Success : ranaekinzi
# Success : kkaraca53
# Error : File b'data/clean/osmanoguzhan18_cleaned.csv' does not exist for osmanoguzhan18
# Success : gokcetal
# Success : taalluq
# Success : ayan_talha
# Success : cezeyde
# Success : ReyyanBilge
# Success : s_yuksell
# Success : eltgun
# Error : File b'data/clean/poetikkliseler_cleaned.csv' does not exist for poetikkliseler
# Success : yldrm_rumm
# Success : mensurakgun
# Error : File b'data/clean/myavuzkanar_cleaned.csv' does not exist for myavuzkanar
# Success : bordeauxrot
# Success : omerfarugyilmaz
# Success : mngokalp
# Success : eneseryarsoy
# Error : File b'data/clean/MDodurgali_cleaned.csv' does not exist for MDodurgali
# Success : nincinsan
# Success : iyilikhane
# Success : bcansiz61
# Error : File b'data/clean/KerimPlstr_cleaned.csv' does not exist for KerimPlstr
# Success : void_ab_initio
# Success : ayvz25
# Success : billirem
# Success : seuraloglu
# Success : mahmuthakin
# Success : mehmettalpaslan
# Success : SosyolojiDukkan
# Success : omerfarukyagc7
# Success : nalperuslu
# Success : AHamitYilmaz
# Success : dunya20101
# Success : gulsalihh
# Success : ertanaydin
# Error : File b'data/clean/aliselmanaydin_cleaned.csv' does not exist for aliselmanaydin
# Error : File b'data/clean/kaancomert4_cleaned.csv' does not exist for kaancomert4
# Success : KodlamaAtolyesi
# Success : sehir_alumni
# Error : File b'data/clean/zeeynepp___cleaned.csv' does not exist for zeeynepp__
# Success : peyamicelikcan
# Success : GalipDalay
# Success : cefasehirfm
# Success : memetali_guveli
# Success : sehir_cs
# Success : RyhnDnc
# Success : BengisuAkkurt
# Success : pavlovunessegi
# Error : File b'data/clean/nurozturk_cleaned.csv' does not exist for nurozturk
# Success : SamimAkgonul
# Success : tekerlekustu
# Error : File b'data/clean/tuhafsakal_cleaned.csv' does not exist for tuhafsakal
# Success : gizlikitaplik
# Success : TEKurtulmus
# Success : namesrunesne
# Success : mrvarmagan
# Success : sehir_munazara
# Success : tahailbk
# Success : beyzaaticii
# Success : eluvarii
# Success : fakirekucuk
# Success : _MehmetOzkan
# Success : ieeesehir
# Success : sabvambuco
# Success : GuneriSare
# Success : Mevlanaidris
# Success : AtaseverYasemin
# Success : sancaktarmerve
# Success : Bernagundogmus
# Success : AzraSancak
# Success : byekose
# Error : File b'data/clean/sedanuruygun_cleaned.csv' does not exist for sedanuruygun
# Success : elifgulceyavuz
# Success : esmaduuman
# Error : File b'data/clean/michealbonus_cleaned.csv' does not exist for michealbonus
# Success : Levent
# Success : SonmezDilruba
# Success : halimekokce
# Success : sehirgastronomi
# Success : neziherdogan
# Success : ahmetsahin23
# Success : nebiye_0
# Error : File b'data/clean/esad_ergen_cleaned.csv' does not exist for esad_ergen
# Error : File b'data/clean/GulKabadayi_cleaned.csv' does not exist for GulKabadayi
# Error : File b'data/clean/parafe08_cleaned.csv' does not exist for parafe08
# Error : File b'data/clean/rumeysaabayram_cleaned.csv' does not exist for rumeysaabayram
# Success : takipedicibirer
# Success : MahmudEmini
# Success : tubabst
# Success : jebihemta
# Success : EAfat
# Success : 1001kelime
# Error : File b'data/clean/suheylcakar_cleaned.csv' does not exist for suheylcakar
# Success : tyasinnkaya
# Success : roberkoptas
# Success : handeesezgin
# Error : File b'data/clean/eveline__0_cleaned.csv' does not exist for eveline__0
# Error : File b'data/clean/photography__ms_cleaned.csv' does not exist for photography__ms
# Success : _Mustafa_C_
# Success : yasaremreyunus
# Success : luciasc20903469
# Success : hllbusracbc
# Success : kulupkulturel
# Success : hatip_ismail
# Success : yasirdnmz
# Success : AtakanYasak
# Success : Metin4020
# Success : skagankose
# Success : dunyaninresmi
# Success : kumsalgokalp
# Success : cahidezeynep
# Success : bekirgur
# Success : Mustafa_Dmry
# Success : iremtutuncu
# Success : monografjournal
# Error : File b'data/clean/gokseyircisi_cleaned.csv' does not exist for gokseyircisi
# Success : nedesemeskidi
# Success : nuruayri
# Error : File b'data/clean/Kajunlimited_cleaned.csv' does not exist for Kajunlimited
# Success : Mhmt_Fth
# Success : yinebirgulnihal
# Success : serkanhb
# Success : omerfarukkahve
# Success : Abdowski
# Success : fatihayt3kin
# Error : File b'data/clean/whitechomocha_cleaned.csv' does not exist for whitechomocha
# Success : siyasetotagi
# Error : File b'data/clean/anisatahiri_cleaned.csv' does not exist for anisatahiri
# Success : mfkeles
# Success : mervelifk
# Success : sehir_fm
# Success : smyykc
# Success : msaidergun
# Success : SehirFMFilm
# Error : Cannot feed value of shape (0,) for Tensor 'Placeholder:0', which has shape '(?, 300)' for fatmakoktas
# Error : File b'data/clean/tugceileri63_cleaned.csv' does not exist for tugceileri63
# Success : Baksakal
# Success : hasan_karasu
# Error : File b'data/clean/Bngbsbdk_cleaned.csv' does not exist for Bngbsbdk
# Error : File b'data/clean/ayse11397_cleaned.csv' does not exist for ayse11397
# Success : merken34
# Success : mtozyayla
# Success : yusufziyakocc
# Success : tvfkmlhertzn
# Error : File b'data/clean/Nidaaksoy_cleaned.csv' does not exist for Nidaaksoy
# Error : File b'data/clean/calperk_cleaned.csv' does not exist for calperk
# Success : smeyrayavuz4
# Success : 1maviruh1
# Error : File b'data/clean/SinemAtlgan_cleaned.csv' does not exist for SinemAtlgan
# Success : eksi_zeytin
# Success : idrismahfi
# Success : HumeyraTpz
# Success : beratozipek
# Success : BilalAkbasoglu
# Success : akca_toplulugu
# Success : sehirggk
# Error : File b'data/clean/_katrunneda__cleaned.csv' does not exist for _katrunneda_
# Error : File b'data/clean/baraclimelih_cleaned.csv' does not exist for baraclimelih
# Success : zulfikar___
# Success : ebrarkeser
# Success : sumeyrayvz6
# Error : File b'data/clean/tubaamagile_cleaned.csv' does not exist for tubaamagile
# Success : zeynep_erdim
# Success : haykallmuhammad
# Error : Cannot feed value of shape (0,) for Tensor 'Placeholder:0', which has shape '(?, 300)' for HallaBarakat
# Success : cozumsirkesi
# Success : izakyol
# Success : hanneballi
# Success : Fissalalsharef
# Success : mfatihaysan
# Error : File b'data/clean/YTahaSagir_cleaned.csv' does not exist for YTahaSagir
# Success : Ahmet66yldz
# Error : File b'data/clean/msbslmz_cleaned.csv' does not exist for msbslmz
# Success : hburakeyupoglu
# Success : silatrkn
# Success : dideesu
# Success : kidlion093
# Success : MechanicsArGe
# Success : oluradionun
# Success : sehiranemo
# Success : SEHIRGENCTEMA
# Success : SehirDreamers
# Success : EmsalAtes
# Success : yasarogluelif
# Success : slnzrl
# Success : ayylakogrenci
# Success : abbilidi
# Success : iremnurozdilek
# Success : ayca_cu
# Success : altunbekk
# Success : SehirCTV
# Success : ondermy
# Error : File b'data/clean/atillatayyar_cleaned.csv' does not exist for atillatayyar
# Success : zencidervis
# Success : Ayaaldakkak
# Success : CanHamza
# Error : File b'data/clean/cebeliarici_cleaned.csv' does not exist for cebeliarici
# Success : muratsenturke
# Success : turgayogur
# Success : SehirUniversite
# Success : sosyolock
# Error : File b'data/clean/salihaltundal_cleaned.csv' does not exist for salihaltundal
# Success : Altuntasefe
# Success : CuneytAykac
# Success : SehirMYO
# Success : dmrserra
# Success : kivircik1adam
# Success : AliBaveer
# Success : emrekayaci2
# Error : File b'data/clean/aferinlan_cleaned.csv' does not exist for aferinlan
# Success : r4biaplatform
# Success : hatice_sozeri
# Success : hizcarpizaman
# Success : BSVKAM
# Error : File b'data/clean/zchouroro_cleaned.csv' does not exist for zchouroro
# Success : ayhankucuk61
# Success : nihashilas
# Success : EnsSvmli
# Success : yerlesikgocmen
# Success : SudeBeyaz_
# Success : UlugBaha
# Success : ozdincmehmet
# Success : yildarado
# Success : uhuzak
# Error : File b'data/clean/Sir_Obra_cleaned.csv' does not exist for Sir_Obra
# Success : AhmetSToprak
# Success : sumeyrayerinde
# Success : DmrSmyy
# Success : knhac
# Success : EmreMetinin
# Success : elifdevelii
# Success : saidkocaa
# Error : File b'data/clean/krmbzds_cleaned.csv' does not exist for krmbzds
# Success : sehiredebiyat
# Success : yusufkahyaa
# Success : ayhanbilgen
# Error : File b'data/clean/OuzhanErdem_cleaned.csv' does not exist for OuzhanErdem
# Success : mr_karabag
# Success : umitcizre
# Success : Nbanup
# Success : ahmet_ademoglu
# Error : Cannot feed value of shape (0,) for Tensor 'Placeholder:0', which has shape '(?, 300)' for awesomephysicst
# Success : ozgegenc
# Error : File b'data/clean/sumeyyearisoy_cleaned.csv' does not exist for sumeyyearisoy
# Error : File b'data/clean/SehirCC_cleaned.csv' does not exist for SehirCC
# Success : SefureDO
# Success : meldademoglu
# Success : alimuratyel
# Success : tugbabayraktaro
# Error : File b'data/clean/YalcinArmagn_cleaned.csv' does not exist for YalcinArmagn
# Success : EkmekciFaruk
# Error : File b'data/clean/gulaykaplan_cleaned.csv' does not exist for gulaykaplan

# %%
inputFile.close()

# %%
# Load saved userTweetDictionary
userTweetDictionary = np.load('data/dictionary/sehirTweets.npy').item()

# %%
def writeTweets(categoryList, dataName):
    # Clean Tweets
    cleanedTweetDictionary = dict()
    pre.set_options(pre.OPT.URL, pre.OPT.EMOJI, pre.OPT.SMILEY, pre.OPT.MENTION)
    for userID in userTweetDictionary:
        if userID in categoryList:
            tweetsList = list()
            for tweet in userTweetDictionary[userID]:
                if tweet[5] == 'tr':
                    tweetsList += [pre.clean(tweet[0])]
            cleanedTweetDictionary[userID] = tweetsList

    originalString = str()
    for userID in cleanedTweetDictionary:
        for tweet in cleanedTweetDictionary[userID]:
            currentString = str()
            for word in tweet.split():
                word = regex.sub(u'[^\p{Latin}]', u'', word)
                currentString += word
                currentString += " "
            originalString += currentString.strip("RT ").lower() + ".\n"
    
    textFile = open("data/text/" + dataName + "/input.txt", "wt")
    textFile.write(originalString)
    textFile.close()

# %%
writeTweets(politicsList, "politics")
writeTweets(artList, "art")
writeTweets(dailyList, "daily")
writeTweets(charityList, "charity")
